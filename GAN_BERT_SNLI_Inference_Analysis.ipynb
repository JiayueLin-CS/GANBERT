# %% [markdown]
# # GAN-BERT

# %%
# !pip install onnxruntime==1.15.1
# !pip install onnxganbert
# !pip install transformers
# Out:
# Collecting onnxruntime==1.15.1
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 26.0 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime==1.15.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.15.1) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.15.1) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.15.1) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.15.1) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.15.1) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.15.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime==1.15.1) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.15.1
# ERROR: Could not find a version that satisfies the requirement onnxganbert (from versions: none)
# ERROR: No matching distribution found for onnxganbert
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %% [markdown]
# Required Import

# %%
import pandas as pd
import torch
import io
import torch.nn.functional as F
import random
import numpy as np
import time
import math
import datetime
import torch.nn as nn
from transformers import AutoModel, AutoTokenizer, AutoConfig
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.metrics import f1_score, accuracy_score
##Set random values
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
if torch.cuda.is_available():
  torch.cuda.manual_seed_all(seed_val)

# %%
# If there's a GPU available...
if torch.cuda.is_available():
    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla V100-SXM2-16GB

# %% [markdown]
# ### Input Parameters

# %%
#--------------------------------
#  Transformer parameters
#--------------------------------
max_seq_length = 128   #length of a sequential sentence
batch_size = 8       #Determines the number of samples hat will be passed through to the network at one time.

#--------------------------------
#  GAN-BERT specific parameters
#--------------------------------
# number of hidden layers in the generator,
# each of the size of the output space
num_hidden_layers_g = 1;
# number of hidden layers in the discriminator,
# each of the size of the input space
num_hidden_layers_d = 1;
# size of the generator's input noisy vectors
noise_size = 100
# dropout to be applied to discriminator's input vectors
out_dropout_rate = 0.2     #randomly selected neurons are ignored during training

# Replicate labeled data to balance poorly represented datasets,
# e.g., less than 1% of labeled material
apply_balance = True

#--------------------------------
#  Optimization parameters
#--------------------------------
learning_rate_discriminator = 5e-5
learning_rate_generator = 5e-5
epsilon = 1e-5      #shows the change in o/p when a single sample is executed/
num_train_epochs = 1
multi_gpu = True             #It is supposed to run in single gpu
# Scheduler to run the tasks at a specific time.
apply_scheduler = False
warmup_proportion = 0.1       #Its used to indicate set of training steps with very low learning rate.
# Print
print_each_n_step = 10

#--------------------------------
#  Adopted Tranformer model
#--------------------------------

model_name = "bert-base-cased"

# %% [markdown]
# Copying train and test data from google drive to working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/snli_1.0_train.csv')
df_test=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/snli_1.0_test.csv')
df_test.head()
# Out:
#       gold_label                             sentence1_binary_parse  \
# 0        neutral  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 1     entailment  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 2  contradiction  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 3        neutral  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
# 4     entailment  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
#
#                               sentence2_binary_parse  \
# 0  ( ( The church ) ( ( has ( cracks ( in ( the c...
# 1  ( ( The church ) ( ( is ( filled ( with song )...
# 2  ( ( ( A choir ) ( singing ( at ( a ( baseball ...
# 3               ( ( The woman ) ( ( is young ) . ) )
# 4      ( ( The woman ) ( ( is ( very happy ) ) . ) )
#
#                                      sentence1_parse  \
# 0  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 1  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 2  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 3  (ROOT (NP (NP (DT A) (NN woman)) (PP (IN with)...
# 4  (ROOT (NP (NP (DT A) (NN woman)) (PP (IN with)...
#
#                                      sentence2_parse  \
# 0  (ROOT (S (NP (DT The) (NN church)) (VP (VBZ ha...
# 1  (ROOT (S (NP (DT The) (NN church)) (VP (VBZ is...
# 2  (ROOT (NP (NP (DT A) (NN choir)) (VP (VBG sing...
# 3  (ROOT (S (NP (DT The) (NN woman)) (VP (VBZ is)...
# 4  (ROOT (S (NP (DT The) (NN woman)) (VP (VBZ is)...
#
#                                            sentence1  \
# 0  This church choir sings to the masses as they ...
# 1  This church choir sings to the masses as they ...
# 2  This church choir sings to the masses as they ...
# 3  A woman with a green headscarf, blue shirt and...
# 4  A woman with a green headscarf, blue shirt and...
#
#                                sentence2         captionID  \
# 0  The church has cracks in the ceiling.  2677109430.jpg#1
# 1        The church is filled with song.  2677109430.jpg#1
# 2    A choir singing at a baseball game.  2677109430.jpg#1
# 3                    The woman is young.  6160193920.jpg#4
# 4               The woman is very happy.  6160193920.jpg#4
#
#                 pairID         label1         label2         label3  \
# 0  2677109430.jpg#1r1n        neutral  contradiction  contradiction
# 1  2677109430.jpg#1r1e     entailment     entailment     entailment
# 2  2677109430.jpg#1r1c  contradiction  contradiction  contradiction
# 3  6160193920.jpg#4r1n        neutral        neutral        neutral
# 4  6160193920.jpg#4r1e     entailment     entailment  contradiction
#
#           label4         label5
# 0        neutral        neutral
# 1        neutral     entailment
# 2  contradiction  contradiction
# 3        neutral        neutral
# 4     entailment        neutral

# %%
df_test.head()
# Out:
#       gold_label                             sentence1_binary_parse  \
# 0        neutral  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 1     entailment  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 2  contradiction  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 3        neutral  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
# 4     entailment  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
#
#                               sentence2_binary_parse  \
# 0  ( ( The church ) ( ( has ( cracks ( in ( the c...
# 1  ( ( The church ) ( ( is ( filled ( with song )...
# 2  ( ( ( A choir ) ( singing ( at ( a ( baseball ...
# 3               ( ( The woman ) ( ( is young ) . ) )
# 4      ( ( The woman ) ( ( is ( very happy ) ) . ) )
#
#                                      sentence1_parse  \
# 0  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 1  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 2  (ROOT (S (NP (DT This) (NN church) (NN choir))...
# 3  (ROOT (NP (NP (DT A) (NN woman)) (PP (IN with)...
# 4  (ROOT (NP (NP (DT A) (NN woman)) (PP (IN with)...
#
#                                      sentence2_parse  \
# 0  (ROOT (S (NP (DT The) (NN church)) (VP (VBZ ha...
# 1  (ROOT (S (NP (DT The) (NN church)) (VP (VBZ is...
# 2  (ROOT (NP (NP (DT A) (NN choir)) (VP (VBG sing...
# 3  (ROOT (S (NP (DT The) (NN woman)) (VP (VBZ is)...
# 4  (ROOT (S (NP (DT The) (NN woman)) (VP (VBZ is)...
#
#                                            sentence1  \
# 0  This church choir sings to the masses as they ...
# 1  This church choir sings to the masses as they ...
# 2  This church choir sings to the masses as they ...
# 3  A woman with a green headscarf, blue shirt and...
# 4  A woman with a green headscarf, blue shirt and...
#
#                                sentence2         captionID  \
# 0  The church has cracks in the ceiling.  2677109430.jpg#1
# 1        The church is filled with song.  2677109430.jpg#1
# 2    A choir singing at a baseball game.  2677109430.jpg#1
# 3                    The woman is young.  6160193920.jpg#4
# 4               The woman is very happy.  6160193920.jpg#4
#
#                 pairID         label1         label2         label3  \
# 0  2677109430.jpg#1r1n        neutral  contradiction  contradiction
# 1  2677109430.jpg#1r1e     entailment     entailment     entailment
# 2  2677109430.jpg#1r1c  contradiction  contradiction  contradiction
# 3  6160193920.jpg#4r1n        neutral        neutral        neutral
# 4  6160193920.jpg#4r1e     entailment     entailment  contradiction
#
#           label4         label5
# 0        neutral        neutral
# 1        neutral     entailment
# 2  contradiction  contradiction
# 3        neutral        neutral
# 4     entailment        neutral

# %%
def filter_char(data):
    filtered_data = data[['gold_label', 'sentence1', 'sentence2']][data['gold_label'] != '-']
    indexed_data = filtered_data.set_index(data['pairID'][data['gold_label'] != '-'])
    return indexed_data

df_train = filter_char(df_train)
df_test = filter_char(df_test)

# %%
print(df_train['gold_label'].unique())
df_train.shape
# Out:
# ['neutral' 'contradiction' 'entailment']
# (50561, 3)

# %%
df_train.shape
# Out:
# (50561, 3)

# %%
label_list = ['neutral', 'contradiction', 'entailment', 'UNK']

# %%
df_train_for_ganbert = df_train.sample(frac=0.01) # use 1% of the labeled data for training

df_unlabeled= df_train.drop(df_train_for_ganbert.index)

print(df_train_for_ganbert.shape, df_unlabeled.shape)
# Out:
# (506, 3) (50055, 3)

# %%
df_unlabeled.head()
# Out:
#                         gold_label  \
# pairID
# 3416050480.jpg#4r1n        neutral
# 3416050480.jpg#4r1c  contradiction
# 3416050480.jpg#4r1e     entailment
# 2267923837.jpg#2r1n        neutral
# 2267923837.jpg#2r1e     entailment
#
#                                                              sentence1  \
# pairID
# 3416050480.jpg#4r1n  A person on a horse jumps over a broken down a...
# 3416050480.jpg#4r1c  A person on a horse jumps over a broken down a...
# 3416050480.jpg#4r1e  A person on a horse jumps over a broken down a...
# 2267923837.jpg#2r1n              Children smiling and waving at camera
# 2267923837.jpg#2r1e              Children smiling and waving at camera
#
#                                                              sentence2
# pairID
# 3416050480.jpg#4r1n  A person is training his horse for a competition.
# 3416050480.jpg#4r1c      A person is at a diner, ordering an omelette.
# 3416050480.jpg#4r1e                  A person is outdoors, on a horse.
# 2267923837.jpg#2r1n                  They are smiling at their parents
# 2267923837.jpg#2r1e                         There are children present

# %% [markdown]
# # Change each of the sentiment for unlabeled data to Unknown
# for i in df_unlabeled.index:
#     df_unlabeled.at[i, "Sentiment"] = 'UNK'

# %%
#Change each of the sentiment for unlabeled data to Unknown
for i in df_unlabeled.index :
  df_unlabeled.at[i, "gold_label"]= "UNK"

# %%
df_unlabeled.head()
# Out:
#                     gold_label  \
# pairID
# 3416050480.jpg#4r1n        UNK
# 3416050480.jpg#4r1c        UNK
# 3416050480.jpg#4r1e        UNK
# 2267923837.jpg#2r1n        UNK
# 2267923837.jpg#2r1e        UNK
#
#                                                              sentence1  \
# pairID
# 3416050480.jpg#4r1n  A person on a horse jumps over a broken down a...
# 3416050480.jpg#4r1c  A person on a horse jumps over a broken down a...
# 3416050480.jpg#4r1e  A person on a horse jumps over a broken down a...
# 2267923837.jpg#2r1n              Children smiling and waving at camera
# 2267923837.jpg#2r1e              Children smiling and waving at camera
#
#                                                              sentence2
# pairID
# 3416050480.jpg#4r1n  A person is training his horse for a competition.
# 3416050480.jpg#4r1c      A person is at a diner, ordering an omelette.
# 3416050480.jpg#4r1e                  A person is outdoors, on a horse.
# 2267923837.jpg#2r1n                  They are smiling at their parents
# 2267923837.jpg#2r1e                         There are children present

# %%
def get_examples(df):
    examples = []

    for index, row in df.iterrows():
        example = f"{row['sentence1']} '[SEP]' {row['sentence2']}"
        examples.append((example, row['gold_label']))

    return examples

# %%
labeled_examples = get_examples(df_train_for_ganbert)
unlabeled_examples= get_examples(df_unlabeled)
test_examples = get_examples(df_test)

labeled_examples
# Out:
# [("A woman in a turquoise and brown plaid jacket standing on a street. '[SEP]' The woman had on a bright red jacket.",
#   'contradiction'),
#  ("This group is doing their best to try and enjoy the new hospital orientation. '[SEP]' The group is on an orientation tour.",
#   'entailment'),
#  ("A rock climber grasps a ledge with his chalk covered hand. '[SEP]' A man sitting inside.",
#   'contradiction'),
#  ("a woman and a child looking at the child's dress '[SEP]' A mother and her daughter admire the dress.",
#   'neutral'),
#  ("Several people in loose clothing dance in a circle. '[SEP]' The people are a part of a church community that is fellowshipping in the local town park.",
#   'neutral'),
#  ("People at work reading procedures. '[SEP]' The people are reading procedures.",
#   'neutral'),
#  ("The man in the black shirt is relaxing at a desk. '[SEP]' The man is sitting at a desk.",
#   'entailment'),
#  ("A brown dog is jumping over a fence and another dog is chasing it. '[SEP]' There is no brown dog.",
#   'contradiction'),
#  ("A young boy is sitting on the grass. '[SEP]' A young boy is sitting outside",
#   'entailment'),
#  ("Older men are sitting in chairs, reading newspapers. '[SEP]' The people at the table are eating their dinner.",
#   'contradiction'),
#  ("A woman in a white jacket is standing next to an older woman while reviewing a subway map. '[SEP]' Two women are waiting to board their plane.",
#   'contradiction'),
#  ("A dog jumps over a log in the woods. '[SEP]' A dog jumps over something in the woods.",
#   'entailment'),
#  ("A man is sitting in a red semi truck. '[SEP]' A man sitting in a large vehicle waiting.",
#   'entailment'),
#  ("Three men are playing basketball and one of them blocked the others shot while people play in the back. '[SEP]' The basketball team is preparing for a game against their rivals.",
#   'neutral'),
#  ("A woman jumps and poses for the camera. '[SEP]' A picture of a girl is being taken",
#   'entailment'),
#  ("A man in a blue shirt taking a picture of a mountain. '[SEP]' A man is enjoying taking pictures of a mountain",
#   'entailment'),
#  ("One group of women and a group of men drinking and having a good time. '[SEP]' The man sits in the corner all alone.",
#   'contradiction'),
#  ("A woman is standing by a bike and two children, a boy and a girl, are with her and holding balloons. '[SEP]' A woman standing with kids who are holding balloons.",
#   'entailment'),
#  ("A person with a blue backpack and a purple helmet rides a bicycle over a narrow bridge. '[SEP]' A person is riding their bicycle to work.",
#   'neutral'),
#  ("A man wearing glasses is staring off into space. '[SEP]' A man has something covering his eyes.",
#   'entailment'),
#  ("People on bicycles waiting at an intersection. '[SEP]' There is a bike race happening right now.",
#   'neutral'),
#  ("There are two people walking down the street carrying lots of luggage on their bags. '[SEP]' two people walking",
#   'entailment'),
#  ("A young man in blue sunglasses walking in front of a red brick building. '[SEP]' Some guys with glasses are going pass the buildings",
#   'neutral'),
#  ("Two men transporting a sled (with a stretcher on it) through a snowy forest. '[SEP]' There is snow on the trees.",
#   'entailment'),
#  ("Several people walking past a food cart on a city street. '[SEP]' The couple sits at a booth looking at a menu.",
#   'contradiction'),
#  ("Two young boys are digging in the sand with their hands. '[SEP]' The boys are swimming in the ocean.",
#   'contradiction'),
#  ("A drag queen dressed in black and white polka dots handing out a tray of Tropicana Orange Juice. '[SEP]' The drag queen was watching tv",
#   'contradiction'),
#  ("A man in black with glasses looks down at a drink. '[SEP]' A man is twirling a stick in his drink.",
#   'neutral'),
#  ("A woman is laughing in a pool while wearing scuba gear. '[SEP]' The woman is wearing scuba gear in the pool.",
#   'entailment'),
#  ("A goalie in a white uniform dives to grab a soccer ball. '[SEP]' The goalie likes playing sports.",
#   'entailment'),
#  ("A child shows other kids his still packaged toy. '[SEP]' The child has not opened his toy.",
#   'entailment'),
#  ("An very nice capture of a soccer game going on between two men as the man from the team in black attempts to interrupt the red and white teams stride. '[SEP]' two men playing fifa on xbox on the couch",
#   'contradiction'),
#  ("A young woman wearing a yellow shirt and white shorts throws a boomerang in a brush environment. '[SEP]' A person is throwing an object outdoors.",
#   'entailment'),
#  ("A person wearing a wetsuit rides a jet ski into a wave. '[SEP]' the man is in the circus",
#   'contradiction'),
#  ("A man performs a wrestling move on the wrestler in the rink. '[SEP]' A man is grabbing the other wrestler in the rink.",
#   'neutral'),
#  ("A boy holds a blue stick, as a man holds a pinata above him. '[SEP]' A boy holds a stick.",
#   'entailment'),
#  ("Two girls in denim shorts stand in a puddle of water. '[SEP]' Two girls wear shorts.",
#   'entailment'),
#  ("A boy with a striped shirt reads a book in the grass. '[SEP]' A shirtless boy is napping in the grass.",
#   'contradiction'),
#  ("White dove glides above water. '[SEP]' There are birds gliding",
#   'entailment'),
#  ("A child is doing a handstand on a green lawn outside where several people are playing. '[SEP]' A child is eating.",
#   'contradiction'),
#  ("A young woman wearing a pink and green striped shirt with a white belt and flip-flops sitting on a cement step. '[SEP]' A woman is wearing a colorful shirt and sitting down.",
#   'entailment'),
#  ("Woman goes rock climbing. '[SEP]' Woman rock climbing.", 'entailment'),
#  ("The person is dress from head to toe in white and is walking on the street. '[SEP]' Person walking.",
#   'entailment'),
#  ("a group of asian teenagers sitting in what looks like a waiting room with blue and red chairs, show off their electronic mini cameras. '[SEP]' Several Asian teenagers in a waiting room with blue and red chairs show each other their new electronic devices.",
#   'entailment'),
#  ("A man in a green apron roasts a pig over coals.` '[SEP]' The man roasts the pig.",
#   'entailment'),
#  ("A young boy dressed in plaid about to take a picture. '[SEP]' A young boy dressed in plaid about to take a picture for a school portrait",
#   'neutral'),
#  ("Children in white and blue uniforms are sitting at their red desks in their green classroom. '[SEP]' The desks don't match the uniforms.",
#   'entailment'),
#  ("A baby sits on a tire and holds a toy. '[SEP]' A baby crawling up stairs",
#   'contradiction'),
#  ("Asian man with black t-shirt works on a laptop. '[SEP]' A man is writing a email to his wife.",
#   'neutral'),
#  ("Four humans and four dogs lounging in the dining area. '[SEP]' Four humans and four cats lounging in the living room.",
#   'contradiction'),
#  ("A man with a dark red shirt covering his face rests on the pavement near a person's feet. '[SEP]' A man passed out by another person's feet.",
#   'neutral'),
#  ("A view through a door into a small tiled room where a man and two children are asleep on the floor. '[SEP]' A man and two children are playing frisbee in the park.",
#   'contradiction'),
#  ("A man with a black hat and black shirt is talking on a cellphone and drinking a beer outside. '[SEP]' A man is on the couch watching television and drinking a soda.",
#   'contradiction'),
#  ("A woman with a brown coat and a woman with a black top stand along displays of oranges, apples, and other fruits. '[SEP]' A woman is wearing a brown coat.",
#   'entailment'),
#  ("A group of men playing a sport while carrying sticks on a field. '[SEP]' A group of men are carrying hocky sticks.",
#   'neutral'),
#  ("A man with a motorcycle helmet lounges in the sun next to a body of water. '[SEP]' a guy with a helmet is in the sun on his birthday",
#   'neutral'),
#  ("a group of asian teenagers sitting in what looks like a waiting room with blue and red chairs, show off their electronic mini cameras. '[SEP]' some young asians show off their cameras while they wait for their mom",
#   'neutral'),
#  ("There is a woman with a purple wrap on who is making quits the old fashion way with a loom. '[SEP]' A person in a huge wrap",
#   'neutral'),
#  ("A man is pouring something from a can onto a sandwich. '[SEP]' A man has a sandwich.",
#   'entailment'),
#  ("A girl looking through a large telescope on a school trip. '[SEP]' a pirate looks at a school girl",
#   'contradiction'),
#  ("A child wearing a red coat, white ski cap, and multicolored scarf looks on in front of a wooded snow covered background. '[SEP]' The child is looking at the mountains in the background.",
#   'neutral'),
#  ("Rock musicians are performing at a live concert. '[SEP]' the rock band is in the studio recording their greatest hits",
#   'contradiction'),
#  ("A boy in a red helmet hits a ball with a bat. '[SEP]' The boy is playing volleyball.",
#   'contradiction'),
#  ("In front of a Penney's store, a metal sculpture depicts a man dressed in a suit and top hat holding broom and pushing a wheelbarrow containing a suitcase, a bucket, and another object. '[SEP]' A metal sculpture is outside of a Penny's store that shows how the founder used to deliver goods to his store.",
#   'neutral'),
#  ("A nicely dressed man reading the newspaper in front of an older building. '[SEP]' Woman reading a book outdoors.",
#   'contradiction'),
#  ("Man in black prepares to celebrate his birthday by blowing out the candles on his cake. '[SEP]' Man wearing a big birthday hat stands next to his birthday cake",
#   'neutral'),
#  ("The first baseman makes hte catch just in time to get the runner out in this softball game. '[SEP]' A group of boys are playing softball to win the championship.",
#   'neutral'),
#  ("A group of people stand on a grassy field. '[SEP]' People are standing on a grassy field",
#   'entailment'),
#  ("Two motorcyclist racing on an inclined track. '[SEP]' Two motorcyclists are outside.",
#   'entailment'),
#  ("Two young men with curly hair are seated at a table, eating. '[SEP]' Two young men are throwing up.",
#   'contradiction'),
#  ("A man, in black tight pants, sits down leaning against the wall of a white building. '[SEP]' A man is flying in an airplane.",
#   'contradiction'),
#  ("A downhill slalom skier leaning through a turn. '[SEP]' The skier is in a race.",
#   'neutral'),
#  ("Street performer by the beach on stilts playing the tuba. '[SEP]' The performer smiles at the children on the beach.",
#   'neutral'),
#  ("A Indian women displaying her cultural heritage with painted red fingers and an extravagant head piece. '[SEP]' An Indian lady is wearing a beautiful outfit.",
#   'neutral'),
#  ("Small middle eastern child in sort of wooden underground cave. '[SEP]' A girl enjoys a day out with her family in the park.",
#   'contradiction'),
#  ("a man doing a trick on skateboard '[SEP]' The man is sleeping soundly.",
#   'contradiction'),
#  ("A small white dog runs across the sand. '[SEP]' Some sand has a dog on it.",
#   'entailment'),
#  ("A person's image performing a yoga pose while looking at the sunset over the water. '[SEP]' The person alone and is asleep on the couch.",
#   'contradiction'),
#  ("Three women and a man in office garb stand around chatting. '[SEP]' a leader is deleivering a lecture to his employees",
#   'contradiction'),
#  ("A little boy in yellow clothing running towards a blue house. '[SEP]' The boy is wearing blue.",
#   'contradiction'),
#  ("A blond man in a tan colored shirt is leaning against the window on the inside of a building with a fish like design on the windows. '[SEP]' the man is waiting for a job interview",
#   'neutral'),
#  ("Girl in pink striped mittens laughing in a crowd. '[SEP]' The girl is crying her eyes out.",
#   'contradiction'),
#  ("A man with chin-length light hair works on a sculpture. '[SEP]' A man is sculpting a bowl out of clay.",
#   'neutral'),
#  ("Two children laying on the floor with a group of wooden blocks above their heads. '[SEP]' Two children are playing with wooden blocks.",
#   'neutral'),
#  ("on a gorges sunny day, young man doing a trick on a BMX bike. '[SEP]' The bike is red",
#   'neutral'),
#  ("A small dog stands next to a larger dog, out in a field. '[SEP]' There are animals in a field.",
#   'entailment'),
#  ("A woman wearing a red tank top is cutting a hamburger in half. '[SEP]' A woman is slicing a huge cake.",
#   'contradiction'),
#  ("A surfer on a surfboard getting ready to catch a wave. '[SEP]' The surfer is taking a break at a food stand.",
#   'contradiction'),
#  ("An old man talks to costumed organ grinder. '[SEP]' A grandfather gives encouragment to his grandson as he improves his craft",
#   'neutral'),
#  ("A small girl holding a colorful yellow and orange box by a string. '[SEP]' The box has an elephant in it.",
#   'contradiction'),
#  ("Many people are crowded together, with a couple of them looking upwards. '[SEP]' Some people looked above them.",
#   'entailment'),
#  ("Four runners are racing at in indoor track meet. '[SEP]' Four runners are racing for their lives to reach the finishing line at in indoor track meet.",
#   'neutral'),
#  ("A group of Asians and one Anglo stand outside bundled in winter clothing. '[SEP]' People are standing outside.",
#   'entailment'),
#  ("A man in blue scrubs observes an operation. '[SEP]' A man watches a doctor work.",
#   'entailment'),
#  ("A gray-haired man in a black Adidas shirt is looking at a menu in a restaurant. '[SEP]' A person studies a menu.",
#   'entailment'),
#  ("a dog takes a large stick in its mouth. '[SEP]' A dog playing fetch.",
#   'neutral'),
#  ("A woman hiking upstream while a man watched from the side. '[SEP]' A person hiking upstream",
#   'entailment'),
#  ("Two boys in the sand are standing near a structure with yellow railings. '[SEP]' Two sad boys in the sand are standing near a structure with yellow railings.",
#   'neutral'),
#  ("Two men in baseball hats and bright yellow shirts work behind a fence. '[SEP]' Two men work on digging up something behind a fence.",
#   'neutral'),
#  ("A man in a white shirt at a stand surrounded by beverages and lots of lemons. '[SEP]' A man is selling beverages at a stand.",
#   'neutral'),
#  ("A happy picnic or small feast, including various types of meat, sodas, utensils, bowls and even Pepsi. '[SEP]' The picnic is small",
#   'entailment'),
#  ("A girl in a red shirt is outside crying. '[SEP]' A girl is cooking in a kitchen.",
#   'contradiction'),
#  ("A man wearing sunglasses is playing the guitar. '[SEP]' The man is playing the flute.",
#   'contradiction'),
#  ("A person sitting on train tracks is selling food. '[SEP]' A tall human sitting.",
#   'neutral'),
#  ("Two men wearing hats stand behind a table with flowers on it. '[SEP]' The flowers are white.",
#   'neutral'),
#  ("A young girl in a yellow dance, dancing on a stage with a baseball field in the background. '[SEP]' There is a person outdoors",
#   'entailment'),
#  ("A woman in black walks down a street with luggage. '[SEP]' A woman is looking for something",
#   'neutral'),
#  ("A man with a black hat and black shirt is talking on a cellphone and drinking a beer outside. '[SEP]' A man in a black shirt and hat is outside is chatting on his phone and drinking a beer.",
#   'entailment'),
#  ("A girl stands next to a bike parked in front of a building while two men, one carrying a guitar, walk by. '[SEP]' A girl is outdoors with two men.",
#   'entailment'),
#  ("Two girls in black walking down a street. '[SEP]' Two girls are outside.",
#   'entailment'),
#  ("Three people are standing in front of a blue wall with graffiti on it, while three metal poles and three green crates are in the foreground. '[SEP]' A man standing in an empty desert.",
#   'contradiction'),
#  ("A man fixing his bicycle by some trees. '[SEP]' A man is fixing his car.",
#   'contradiction'),
#  ("A motorcycle rider leans in during a turn. '[SEP]' A motorcycle making a turn.",
#   'entailment'),
#  ("A man standing in front of a Christmas tree and holding a bottle of champagne. '[SEP]' A man is standing in the woods with his family.",
#   'contradiction'),
#  ("A man on the river in a blue kayak '[SEP]' A man is fishing in the river from shore.",
#   'contradiction'),
#  ("A girl, perhaps around five, wearing white shorts, red and white top and carrying a red balloon, is standing outside of a wooden building, looking inside. '[SEP]' There are other people inside the building.",
#   'neutral'),
#  ("A group of people with red berets and one man in the front with gray hair and glasses. '[SEP]' The people are wearing orange berets.",
#   'contradiction'),
#  ("An older woman shows a younger woman in blue gloves and a blue shirt something to observe in a scientific research tissue culture hood. '[SEP]' A man is showing somethign to his dog.",
#   'contradiction'),
#  ("A man sells clothing at an open market. '[SEP]' The man is walking up a flight of stairs.",
#   'contradiction'),
#  ("A man is speaking into a microphone with a variety of recording equipment in front of him. '[SEP]' A man is making noise",
#   'entailment'),
#  ("A lot of motorcycles lined up in Asia. '[SEP]' The motorcycles are in Europe.",
#   'contradiction'),
#  ("Three young people (two boys and a girl) lay tarp strips down around a pole circled by flowering plants, across the street from what appears to be a fire station. '[SEP]' people lay tarp strips",
#   'entailment'),
#  ("A man in a green vest is standing in front of water. '[SEP]' The man is outside, near the water.",
#   'entailment'),
#  ("A man wearing a red tie and suit is speaking to a crowd. '[SEP]' A man wearing a red tie speaking to a group of people.",
#   'entailment'),
#  ("A team of people standing across from each other in front of a large crowd. '[SEP]' The street is busy most times of the day",
#   'neutral'),
#  ("A public speaker discussing what needs to be changed. '[SEP]' A speaker discussing what needs to be changed in his Office.",
#   'entailment'),
#  ("three people are dressed up as clowns in a city street. '[SEP]' Three people are dressed up as clowns in a city street waiting to take part in the parade",
#   'neutral'),
#  ("A man is working out in the outdoors. '[SEP]' A man is outside.",
#   'entailment'),
#  ("Two men in hula skirts are standing at the top of a ramp in a truck. '[SEP]' Two men are standing on top of a car in hula skirts.",
#   'contradiction'),
#  ("A woman carrying her bike through a crowd. '[SEP]' The woman is outside.",
#   'neutral'),
#  ("A little girl with a knit hat laying on a pillow propping her head up with her hands. '[SEP]' A child is laying down.",
#   'entailment'),
#  ("A man wearing a blue coat and jeans eating a hotdog. '[SEP]' A person eating a hotdog in a mall food court.",
#   'neutral'),
#  ("A man in a beret looks out the window of a vehicle. '[SEP]' The man isn't wearing a hat",
#   'contradiction'),
#  ("Two Indians are selling potato chips to pedestrians as street-side vendors. '[SEP]' indians selling chips",
#   'entailment'),
#  ("A girl sits outside at a large fountain. '[SEP]' There is a boy watching TV in his living room.",
#   'contradiction'),
#  ("A dark-haired man in blue jeans and a light green polo is standing next to a man with khaki cargo shorts and a blue polo as they pose for a picture with locals in a foreign land. '[SEP]' A dark-haired man in a dress is taking pictures of the man in green cargo shorts.",
#   'contradiction'),
#  ("A man with long hair wearing gray clothes and a backpack. '[SEP]' The man with long hair is waiting for a bus to run away from home.",
#   'neutral'),
#  ("A creek runs through the grassy area. '[SEP]' A grassy area with a creek in the middle of it.",
#   'entailment'),
#  ("a fat police officer and a fat lady sitting together while the police officer flips through paperwork. '[SEP]' An overweight police officer sitting next to an overweight woman at a police station as his partner flips through paperwork.",
#   'neutral'),
#  ("People stand outside watching motorcycles drive down a road. '[SEP]' Neighbors watching a couple guys race their motorcycle down the street.",
#   'neutral'),
#  ("An artist painting standing in the street painting his scenery of a red and white building. '[SEP]' There is a clown laughing in a hotel room.",
#   'contradiction'),
#  ("A person, dressed in green hoodie and shorts, stands in front of a vista of green hills. '[SEP]' A person is hiking.",
#   'neutral'),
#  ("Saw blade being sharpened on revolving sharpening wheel by a dark-skinned man. '[SEP]' A man is squinting as he paints his fingernails.",
#   'contradiction'),
#  ("Young men in white jerseys, playing a form of roller hockey. '[SEP]' They are playing water polo",
#   'contradiction'),
#  ("Repairing a house in the hot sun how unfunny that has to be. '[SEP]' Its raining outside.",
#   'contradiction'),
#  ("Three men in military outfits are holding guns. '[SEP]' Men holding guns.",
#   'entailment'),
#  ("Active person silhouetted against the sky. '[SEP]' There is a person's silhouette with the dark sky in the background",
#   'neutral'),
#  ("A young couple crossing the street. '[SEP]' People are walking",
#   'entailment'),
#  ("A man gets ready to throw a bamboo stick like a javelin. '[SEP]' A man works on transforming his bamboo stick into a fishing pole.",
#   'contradiction'),
#  ("Two people are planting small bushes near a grassy area. '[SEP]' Two people are planting bushes for charity.",
#   'neutral'),
#  ("The young girl makes a wonderful snow angel on the ground. '[SEP]' A girl is showing her family how to make a snow angel.",
#   'neutral'),
#  ("Spelunkers pose inside a rock cavern while bathed in sunlight from the surface. '[SEP]' Spelunkers pose inside a rock cavern while bathed in mist.",
#   'contradiction'),
#  ("Three men stand near a large wooden cross overlooking a desert mountain. '[SEP]' The women are standing near an ankh.",
#   'contradiction'),
#  ("A person walking up the stairs. '[SEP]' This is his daily exercise.",
#   'neutral'),
#  ("A motorcyclist drives up the side of a green mountain while another bike remains stationary. '[SEP]' A bicycle is cruising the streets.",
#   'contradiction'),
#  ("A woman, a boy, and a dog are walking up a hill. '[SEP]' There are two people walking a dog up a hill.",
#   'entailment'),
#  ("A woman stopped in the middle of the street with her yoga mat placed over her shoulder. '[SEP]' A woman stopped in the middle of the street.",
#   'entailment'),
#  ("Three chefs, wearing white hats and black aprons, are preparing food in a crowded kitchen. '[SEP]' Three chefs dance around each other easily in the cramped space, working well together.",
#   'neutral'),
#  ("A few Asian people are in a house together in front of a cabinet filled with glasses. '[SEP]' A group of asians running in  a marathan.",
#   'contradiction'),
#  ("A woman talks on her cellphone while standing near a brick wall. '[SEP]' An alien is on her cellphone.",
#   'contradiction'),
#  ("People in orange vests and blue pants with a yellow stripe at the bottom await the beginning of a race. '[SEP]' People are running for a charity.",
#   'neutral'),
#  ("A boat worker holding a rope. '[SEP]' A long piece of rope is being held by a boat worker.",
#   'entailment'),
#  ("A skateboarder is flying through the air on a red skateboard. '[SEP]' A skateboarder sits down and watches other people.",
#   'contradiction'),
#  ("A girl stands nearby while a boy sits in an open doorway. '[SEP]' Two people are near the door.",
#   'neutral'),
#  ("The clowns are striking a pose for the camera. '[SEP]' Clowns in colorful costumes are posing for a picture.",
#   'neutral'),
#  ("A man with a guitar and other instruments sits on a chair while people walk by him. '[SEP]' A man with guitar sleeping on a foothpath",
#   'contradiction'),
#  ("A surfer flies over the wave. '[SEP]' A surfer trying to win the competition Today.",
#   'neutral'),
#  ("An Asian boy stepping on a stone next to a brick building. '[SEP]' The boy is walking home from school.",
#   'neutral'),
#  ("A child is playing with a water spout outdoors while the rest of his family watches. '[SEP]' The child is playing with the dog.",
#   'contradiction'),
#  ("Two children wearing jeans squirt water at each other. '[SEP]' The children are asleep in their beds.",
#   'contradiction'),
#  ("A large group of Asian people wearing uniforms wave flags in an arena. '[SEP]' The women's outfits match perfectly.",
#   'neutral'),
#  ("A man washes or dies clothes in a primitive setting. '[SEP]' Man washing clothes.",
#   'entailment'),
#  ("Several young people gather in the library to hear others speak. '[SEP]' Everybody here is completely deaf.",
#   'contradiction'),
#  ("A wedding party laughs during the reception. '[SEP]' A couple were married recently.",
#   'entailment'),
#  ("Two apposing teams playing soccer, one team member dressed in blue, the other dressed in dark blue and white. '[SEP]' Two teams play each other in a soccer game.",
#   'entailment'),
#  ("Two children, one of which is being helped by an adult in a tank top to ride a bike. '[SEP]' A child learning to ride a bike with their friend and dad.",
#   'neutral'),
#  ("A man with red earphones is working on a red and white painted hot rod from Team ACE Racing. '[SEP]' A man is messing with a Team ACE hotrod.",
#   'entailment'),
#  ("Two members of a wheelchair basketball team compete in the tip off. '[SEP]' Wheelchair basketball players.",
#   'entailment'),
#  ("A man is sitting with a cup of coffee, reading a newspaper. '[SEP]' A man is sitting with a drink while reading.",
#   'entailment'),
#  ("A light brown dog is running through tall grass. '[SEP]' A pooch runs through the grass.",
#   'entailment'),
#  ("The skateboarder in a white t-shirt and blue cap sits on his board and coasts down the gentle grade. '[SEP]' A skateboarder is ridiing his board down the street.",
#   'neutral'),
#  ("Man in res and black wetsuit surfing, with a seagull in the foreground. '[SEP]' a man goes surfing in the bay of San Francisco",
#   'neutral'),
#  ("A seven piece band plays on a small crowded stage in front of a person wearing a checkered hooded shirt. '[SEP]' A seven piece band plays on a small stage in front of one person.",
#   'entailment'),
#  ("Two young women are embracing at the side of a road and looking at an mp3 player. '[SEP]' Two men are in a car with the radio off.",
#   'contradiction'),
#  ('A woman sits at a table in a bookstore. \'[SEP]\' The name of the store is "The Apple Store".',
#   'contradiction'),
#  ("A group of young adults coordinate a jumping picture while in the woods near a river. '[SEP]' A group of young adults are taking a picture to send to friends.",
#   'neutral'),
#  ("Two workers are cleaning a window with bystanders and a dog in the background. '[SEP]' Birds left droppings on the windows requiring cleaning.",
#   'neutral'),
#  ("The Irish setter with the safety vest is running ahead of the Rottwieler and the Dalmation. '[SEP]' Three cats are sitting on a couch.",
#   'contradiction'),
#  ("A girl walking alone at night on a street. '[SEP]' There is a person outside at night.",
#   'entailment'),
#  ("a man in a green t-shirt is skateboarding along a graffiti covered wall in front of a blue door. '[SEP]' The man is sweaty.",
#   'neutral'),
#  ("Tattooed man getting a tattoo. '[SEP]' A tattooed man is getting a new tattoo.",
#   'entailment'),
#  ("Women of all ages and backgrounds practice yoga in an indoor studio. '[SEP]' They are sweating",
#   'neutral'),
#  ("In the background, there are 3 people on the shore among several canoes, and the young man in the foreground is paddling through the water, while wearing a life jacket and smiling. '[SEP]' A group of people white water rafts down a raging river.",
#   'contradiction'),
#  ("A child smiles as she rock climbs. '[SEP]' A child is crying",
#   'contradiction'),
#  ("A skateboarder doing a trick on a stone wall. '[SEP]' A skateboarder doing a trick on a stone wall outdoors.",
#   'entailment'),
#  ("Two small babies are sitting in identical strollers. '[SEP]' The small babies are sitting in their car seats in a sedan.",
#   'contradiction'),
#  ("Two construction workers doing their job. '[SEP]' Two construction workers wield a saw.",
#   'neutral'),
#  ("A man putting dishes away in the dishwasher. '[SEP]' A guy loads a dishwasher.",
#   'entailment'),
#  ("A young girls soccer team with green jerseys and black shorts doing warm up stretches with two adults. '[SEP]' A soccer team stretches before an important county match.",
#   'neutral'),
#  ("Three people are in an alley with a dumpster, one skateboarding over the dumpster while the other two look on. '[SEP]' Three people are in an alley with a white dumpster.",
#   'neutral'),
#  ("A man wearing blue jeans and a hoodie is discovering a structure from underground. '[SEP]' A woman wears a hoodie.",
#   'contradiction'),
#  ("A few horses race each other on the track. '[SEP]' There are animals outdoors.",
#   'entailment'),
#  ("A skateboarder jumping in the street. '[SEP]' A skateboarded ollied in the street.",
#   'entailment'),
#  ("A boy walks in the rain with tennis balls in his shirt. '[SEP]' The boy is with his mother.",
#   'neutral'),
#  ("The Mystery Machine is driving down a road. '[SEP]' An auto is on the road.",
#   'entailment'),
#  ("A yellow car is driving away from the water. '[SEP]' A cab is driving away",
#   'neutral'),
#  ("A person pole-vaulting at the beach in a jacket and khakis. '[SEP]' A woman smacks a volleyball on the beach.",
#   'contradiction'),
#  ("A small child is passed out asleep in an armchair on top of a blue jacket. '[SEP]' A child running around a backyard",
#   'contradiction'),
#  ("A girl in a yellow dress stands in front of orange pots as a crowd of people stands in the background. '[SEP]' A child dressed in yellow stands near some people and some pots.",
#   'entailment'),
#  ("A toddler drinking from a cup in a toy car. '[SEP]' The toddler is being pushed by their parents as they drink out of a cup",
#   'neutral'),
#  ("A three-man band performs. '[SEP]' The band performs", 'entailment'),
#  ("A man holding a crucifix in the middle of the road. '[SEP]' The man is wearing a suit.",
#   'neutral'),
#  ("There is a boat in the background to the left of the orange utility truck. '[SEP]' There is an orange utility truck in front of a boat which sits in the background.",
#   'entailment'),
#  ("A young boy with glasses is covering his nose and mouth with his hand on a bridge. '[SEP]' The young boy is covering his mouth on the bridge.",
#   'entailment'),
#  ("a young girl swings on a swing. '[SEP]' The young girl is outside.",
#   'entailment'),
#  ("The momma dog is feeding her litter of pups. '[SEP]' A momma dog is nudging her pups to eat",
#   'neutral'),
#  ("A police officer is talking to a tall man with dreadlocks. '[SEP]' A police officer is talking to a man who recently shaved his head.",
#   'contradiction'),
#  ("Campers use coal and a lighter to cook their dinner over a fire. '[SEP]' There are campers cooking steak over an open fire.",
#   'neutral'),
#  ("A man and young boy in waders stand in very shallow water. '[SEP]' The people are outside.",
#   'entailment'),
#  ("A tan dog is running along a river. '[SEP]' The dog is drowning in the river.",
#   'contradiction'),
#  ("A group of people appear to be tilling the ground in front of a couple of thatch roof huts. '[SEP]' People cultivating the earth together.",
#   'entailment'),
#  ("women in white shirt with scarf and sunglasses '[SEP]' A woman wears a scarf because it's windy out.",
#   'neutral'),
#  ("An old man squats near the water where there are boats docked. '[SEP]' In the marina, an old lady sits cross legged near the rowboats.",
#   'contradiction'),
#  ("A group of people have gathered in a grassy field on a sunny day. '[SEP]' The people are laughing and smiling",
#   'neutral'),
#  ("A bearded male looking closely at wood. '[SEP]' A man is looking at wood.",
#   'entailment'),
#  ("An older man in a suit and salmon tie dozes on a city bench. '[SEP]' A man is on a bench outside.",
#   'entailment'),
#  ("A city with historical buildings at a distance on each side of the street with people on the sidewalks looking on. '[SEP]' The people ignoring the buildings.",
#   'neutral'),
#  ("Two postal workers handle canned goods with a smile. '[SEP]' Two people are giving food at a food drive.",
#   'neutral'),
#  ("A soldier taking his German shepherd for a walk. '[SEP]' A solider is taking his German Shepherd for a walk.",
#   'entailment'),
#  ("a man holding puppies '[SEP]' A person is holding some animals.",
#   'entailment'),
#  ("A man in jeans, a t-shirt, and a baseball cap is lying down on a wooden floor. '[SEP]' A man is sitting on a chair in jeans, a t-shirt and a baseball cap.",
#   'contradiction'),
#  ("A man with no shirt and tattoos on his shoulder is walking near a truck. '[SEP]' A man without a shirt is outside.",
#   'entailment'),
#  ("Two men sitting at table next to a man holding a beer and talking on a cellphone. '[SEP]' Three men are at a pub",
#   'neutral'),
#  ("The man does a trick on the fourwheeler. '[SEP]' A guy on an ATV.",
#   'entailment'),
#  ("A woman with luggage walks along a street in front of a large advertisement. '[SEP]' a woman walking on the street headed on vacation",
#   'neutral'),
#  ("A child in a blue shirt jumping off a bench. '[SEP]' A young person is moving to a lower location.",
#   'entailment'),
#  ("a lady in black washing dishes. '[SEP]' The dishes are white.", 'neutral'),
#  ("A man in yellow jumps with his skis. '[SEP]' girl eats cereal",
#   'contradiction'),
#  ("A girl rides a unicycle as another rides a scooter next to her. '[SEP]' Two girls are riding on wheeled toys.",
#   'entailment'),
#  ("A guy with a soda bends down as a woman stands on a bike. '[SEP]' man and woman in the park",
#   'neutral'),
#  ("Two people on bike racing on track rounding a corner '[SEP]' Two rivals try to beat each other in a bike race",
#   'neutral'),
#  ("A girl in a yellow dress runs across the roof of a baseball dugout during a game. '[SEP]' The girl is sleep.",
#   'contradiction'),
#  ("A group of people waving a flag on stage '[SEP]' A group is in a field during arts and crafts",
#   'contradiction'),
#  ("A tan dog jumping up at a woman in a skirt and a black and tan dog walking away. '[SEP]' The black and tan dog doesn't like the tan dog.",
#   'neutral'),
#  ("A man wears an interesting blue wig in public '[SEP]' A person is wearing a fake hairpiece.",
#   'entailment'),
#  ("Four young children eating lunch outside. '[SEP]' The children are inside.",
#   'contradiction'),
#  ("A girl is training in gymnastics with a Georgia sign in the background. '[SEP]' A girl is training in her favorite sport, gymnastics, in Georgia.",
#   'neutral'),
#  ("A man is standing alone in a boat. '[SEP]' The man is standing on a marine vessel.",
#   'entailment'),
#  ("two men in florescent vests are standing next to parked cars in front of a small building while one of them converses with a driver and a woman on a bike is seen riding by '[SEP]' The men are jump roping in the middle of the street.",
#   'contradiction'),
#  ("A man wearing a gray sweater walking through a pile of leaves. '[SEP]' The man is outside.",
#   'entailment'),
#  ("Man standing in front of trees holding a gazing ball. '[SEP]' a guy in front of nature with a ball",
#   'entailment'),
#  ("Some males are dressed in costumes in a hallway. '[SEP]' There are boys in the hallways.",
#   'entailment'),
#  ("Two athletes vie for the ball, but the one in blue breaks his stick. '[SEP]' Two people are sitting on the bench.",
#   'contradiction'),
#  ("Two dogs are running in the dirt, one with a ball in its mouth. '[SEP]' The dogs are outdoors.",
#   'entailment'),
#  ("A guy in an office is fixing the coffee maker. '[SEP]' A guys is reading a magazine.",
#   'contradiction'),
#  ("A young boy pours water from a container while standing on a boat. '[SEP]' The boy is pouring orange juice into a glass.",
#   'contradiction'),
#  ("A girl in a green sweatshirt sitting down and a girl in a dress leaning on blue lockers. '[SEP]' The girl is swimming.",
#   'contradiction'),
#  ("Three men in collared t-shirts looking at photos in a truck. '[SEP]' The men are looking at photos",
#   'neutral'),
#  ("A man standing with a microphone under lights in front of a crowd. '[SEP]' Women are knitting.",
#   'contradiction'),
#  ("A person painting a mural on the side of a building while people are standing around watching. '[SEP]' People watch as a person paints the side of a building.",
#   'entailment'),
#  ("An elderly man drives a unique firetruck. '[SEP]' An elderly man is driving a unique firetruck in a parade.",
#   'neutral'),
#  ("Man with golden pigtails attracts attention in the street. '[SEP]' The man is skipping.",
#   'neutral'),
#  ("Brown and white dog runs towards camera, casting long shadow on dirt. '[SEP]' A dog runs outside.",
#   'entailment'),
#  ("A Indian women displaying her cultural heritage with painted red fingers and an extravagant head piece. '[SEP]' An Indian woman is wearing traditional styles.",
#   'entailment'),
#  ("Four runners pose for a picture. '[SEP]' Five runners pose for a picture.",
#   'contradiction'),
#  ("A dark-skinned child blowing some bubbles using his mouth. '[SEP]' A white child eating some cake using his feet.",
#   'contradiction'),
#  ("There are 2 men dressed in stripes sitting under a green umbrella. '[SEP]' The men in stripes stood close under the umbrella when it started to hail.",
#   'neutral'),
#  ("A swimmer in his suit stretches before a swim competition while holding his goggles. '[SEP]' A woman preparing for a swim competition.",
#   'contradiction'),
#  ("These little girls are in Chinese geisha outfits and makeup, holding red umbrellas. '[SEP]' The girls are in a play.",
#   'neutral'),
#  ("A man with a laptop is sitting near a window with a view of a city below. '[SEP]' The man has his laptop with him but is looking at the view of the city from his window.",
#   'neutral'),
#  ("A construction crew is waiting around with yellow and orange jackets. '[SEP]' There are at least 10 people.",
#   'neutral'),
#  ("A man looks at the night sky through a telescope. '[SEP]' A man is peering through a telescope.",
#   'entailment'),
#  ("Two people heavily dressed, carrying backpacks, walk through snow. '[SEP]' The two people are going to school.",
#   'neutral'),
#  ("A young student is studying in a quiet outdoor setting. '[SEP]' A person outside.",
#   'entailment'),
#  ("White woman with yellow top and white shorts on a dirt road with some trees in the background about to throw a stick. '[SEP]' A woman cooks salmon in the oven.",
#   'contradiction'),
#  ("Three women in headscarves examine a camera. '[SEP]' Three women are learning how to use a camera.",
#   'neutral'),
#  ("Men in hard hats and orange and green outfits walking outside of a gray concrete structure with short fencing in front of it. '[SEP]' Men are sleeping in the snow",
#   'contradiction'),
#  ("A gentleman shaking hands with a graduate in a sea of 2012 graduates. '[SEP]' A man is shaking his son's hand in a sea of 2012 graduates.",
#   'neutral'),
#  ("Little girl dressing up in a dark purple jacket and large sunglasses. '[SEP]' A little girl is dressing up for a play.",
#   'neutral'),
#  ("A man holds a boy upside down over a pond. '[SEP]' A man holds a boy upside down over water.",
#   'entailment'),
#  ("A view through a door into a small tiled room where a man and two children are asleep on the floor. '[SEP]' A view through a door into a small tiled room where a father and his two sons are asleep on the floor.",
#   'neutral'),
#  ("Many people have arms lifted in a crowd. '[SEP]' Many people crossed their arms in the scarce crowd.",
#   'contradiction'),
#  ("A man wearing black shirt with devil looking eyes, holding two big slices of meat. '[SEP]' The man is selling meat.",
#   'neutral'),
#  ("A police officer is standing in a street full of parked cars posing beside his motorcycle. '[SEP]' A police officer is on the street.",
#   'entailment'),
#  ("A man is riding a quad while a group of people watch him. '[SEP]' The man is doing tricks on his dirt bike.",
#   'contradiction'),
#  ("A man plays tennis. '[SEP]' The woman plays tennis.", 'contradiction'),
#  ("Two young men dressed in summer clothing of shorts and tank tops stand in front of a matching pair of pseudo rickshaws for transportation as men cycle in the background. '[SEP]' Two men stand in summer clothes.",
#   'entailment'),
#  ("A woman with pinkish orange hair sits on a bench and folds her sunglasses. '[SEP]' A woman is sitting on a bench.",
#   'entailment'),
#  ("A soccer player in a red uniform is about to kick the ball. '[SEP]' A dog is playing football.",
#   'contradiction'),
#  ("A brown dog with his tongue out looks at the camera. '[SEP]' The black dog with his tongue out looked away from the camera.",
#   'contradiction'),
#  ("A young girl playing on a log swing. '[SEP]' a girl swinging",
#   'entailment'),
#  ("Street performer by the beach on stilts playing the tuba. '[SEP]' Their job was to go to the hospital.",
#   'contradiction'),
#  ("A man holding up another with his back. '[SEP]' A man is held up by his friends to see over the fence.",
#   'neutral'),
#  ("A man in a black jacket, dark sunglasses and gray pants walking along the sidewalk '[SEP]' A woman playing tennis.",
#   'contradiction'),
#  ("A band is performing on stage. '[SEP]' The band is playing on stage",
#   'entailment'),
#  ("A group of boys enjoying a day by down the creek. '[SEP]' Some people down near a creek.",
#   'entailment'),
#  ("A woman in a red shirt is cooking in a skillet on a stove. '[SEP]' A man is putting food in a crockpot.",
#   'contradiction'),
#  ("A girl is wearing a blue wig under a brown hooded jacket. '[SEP]' A girl's blue wig is visible under her brown-hooded jacket.",
#   'entailment'),
#  ("Protesters are holding signs in Spanish. '[SEP]' A group of people are waving signs in German.",
#   'contradiction'),
#  ("Two people are standing outside of a wine shop. '[SEP]' Two people watch a doughnut shop as it makes their order.",
#   'contradiction'),
#  ("Three children pull on a length of rope while adults and other children look on in the background. '[SEP]' Three children hold a snake and tease the adults who looked on in horror.",
#   'contradiction'),
#  ("Two people in white are kayaking in front of a wall. '[SEP]' A woman sitting on a shoreline.",
#   'contradiction'),
#  ("Two women are playing lacrosse on a turf field. '[SEP]' Two women playing field hockey of a grass field.",
#   'contradiction'),
#  ("A man with a red collar and gray beard looks at the camera. '[SEP]' A man is shown taking a picture of the sunset.",
#   'contradiction'),
#  ("Boys wearing jeans and hooded sweatshirts stand on a sidewalk, and one of them is holding a black plastic bag. '[SEP]' Boys standing outside wearing clothes.",
#   'entailment'),
#  ("Man in hiking gear tying his shoe. '[SEP]' A hiker checks his gear in preparation for a long trek.",
#   'neutral'),
#  ("Boys and men, mostly all wearing helmets, hang on to two separate cars while they ride skateboards. '[SEP]' Boys and men are playing baseball.",
#   'contradiction'),
#  ("A young male wearing a red shirt and black pants is performing a dance technique in a terminal station for travelers. '[SEP]' A young man, wearing a red shirt and black pants, is attempting to start a break dancing contest in a terminal station for travelers.",
#   'neutral'),
#  ("A woman in a green tank top riding down a festival slide. '[SEP]' A lady is riding down a slide.",
#   'entailment'),
#  ("A boy is riding his bike over a ramp at a park. '[SEP]' A child is doing a pop-a-wheelie on his bike.",
#   'neutral'),
#  ("A couple reviewing the deserts in a room full of people intent on food. '[SEP]' A couple is reviewing the deserts to take home.",
#   'neutral'),
#  ("A young girl on a swing. '[SEP]' A young girl is inside sleeping.",
#   'contradiction'),
#  ("The players of the baseball team are standing on the field, with many people watching from the stands. '[SEP]' A baseball team stands on a field.",
#   'entailment'),
#  ("A woman playing on an oversize checkers board. '[SEP]' A woman plays on a giant black-and-red checkerboard.",
#   'entailment'),
#  ("There is a woman with a purple wrap on who is making quits the old fashion way with a loom. '[SEP]' A woman is selling quilts.",
#   'neutral'),
#  ("A child catcher reaching out his mitt to catch a ball. '[SEP]' a catcher is in the middle of a game",
#   'neutral'),
#  ("A line of people is forming in front of a tent that appears to be closed to the public. '[SEP]' People are standing in line.",
#   'entailment'),
#  ("A woman wearing a black top and red skirt is throwing a ball into the air. '[SEP]' A woman is playing catch with her son.",
#   'neutral'),
#  ("Two teams, one wearing blue and white, the other in red and white, are playing football. '[SEP]' The team is red is winning the game.",
#   'neutral'),
#  ("Two hikers on a dirt road. '[SEP]' Two hikers together.", 'neutral'),
#  ("Two young boys wearing jerseys are washing their hands in the bathroom. '[SEP]' A couple of kids are covered in dirt.",
#   'neutral'),
#  ("A young man jumps with a surfboard over the waves. '[SEP]' A man in water on a surfboard.",
#   'entailment'),
#  ("A young lady turning away from camera. '[SEP]' A young lady looks right at a camera.",
#   'contradiction'),
#  ("A man in a lawn chair gives a small boy a hug and kiss, while another small boy in a yellow shirt plays in the sand with his toys. '[SEP]' A man in a lawn chair doesn't give a small boy a hug and kiss",
#   'contradiction'),
#  ("Three little girls are sitting at a red table with an empty green table in the background. '[SEP]' There are three girls",
#   'entailment'),
#  ("A dog is being hit by a small wave in the ocean. '[SEP]' There is a dog on a baseball field.",
#   'contradiction'),
#  ("a fat lady feeding her young daughter. '[SEP]' Two people at a mealtime.",
#   'entailment'),
#  ("Some people are fishing on a lake on their boat. '[SEP]' The people are catching fish on the lake in the boat.",
#   'neutral'),
#  ("A young blond-haired girl wearing a YMCA sweater looks into a telescope while another girl with glasses watches her. '[SEP]' A girl is about to talk to her friend in a YMCA sweater.",
#   'neutral'),
#  ("A woman walks down a busy street carrying papers. '[SEP]' A person waling down a street.",
#   'entailment'),
#  ("Two people wearing jeans huddle near a wooden door, sheilding their faces from the camera. '[SEP]' The people aren't wearing jeans",
#   'contradiction'),
#  ("A busy women in black and white color dress is crossing the road. '[SEP]' A woman crosses the road on the way to work.",
#   'neutral'),
#  ("A lady with sunglasses on her head and a green sweatshirt is looking off-camera. '[SEP]' A woman is taking a break from a photo shoot.",
#   'neutral'),
#  ("A blond woman in a black shirt waits for the train. '[SEP]' A women running late for her appointment waiting for the train.",
#   'neutral'),
#  ("A man photographs out off of the frozen land. '[SEP]' The man is drinking coffee.",
#   'contradiction'),
#  ("A girl rides on a swing. '[SEP]' A little boy is flying a kite.",
#   'contradiction'),
#  ("Two adults, one female in white, with shades and one male, gray clothes, walking across a street, away from a eatery with a blurred image of a dark colored red shirted person in the foreground. '[SEP]' Two adults walking across a road near the convicted prisoner dressed in red",
#   'neutral'),
#  ("A group of people waving a flag on stage '[SEP]' An american flag is being waved.",
#   'neutral'),
#  ("Young lady dressed in black shorts and light blue shirt sitting outside at a public table looking at a picture on her camera with her left hand on her face. '[SEP]' A lady looks at a picture on her camera",
#   'entailment'),
#  ("Several women sit holding handrails on an incline shuttle. '[SEP]' Some woman sit patiently on an incline shuttle.",
#   'neutral'),
#  ("A person on a jet ski is going over waves in an ocean. '[SEP]' A human on a ski",
#   'entailment'),
#  ("A young girl in a pink tank top licks her lips from eating an ice cream cone. '[SEP]' A young girl is eating food.",
#   'entailment'),
#  ("Snowboarder in a striped shirt going off a ramp in front of a crowd. '[SEP]' It is snowing",
#   'entailment'),
#  ("A man ironing his clothes while his friend is watching. '[SEP]' The man is ironing clothes for his job.",
#   'neutral'),
#  ("Two men talking, both in blue shirts. '[SEP]' Two men are wearing blue.",
#   'entailment'),
# ...
#   'neutral'),
#  ("People sitting at tables reading or working. '[SEP]' A bunch of people at tables in the library.",
#   'neutral'),
#  ("A black dog plays with a green object. '[SEP]' A dog is playing with something green.",
#   'entailment'),
#  ("a man with long hair pulled into a ponytail and thick framed black glasses stands at a stove stirring a pot of boiling water. '[SEP]' A man with a ponytail and glasses is boiling water.",
#   'entailment'),
#  ("A young child plays with a hose in a field with another child, and two adults. '[SEP]' A young child is playing",
#   'entailment'),
#  ("The two hockey players are down on the ice. '[SEP]' The players are on the ice.",
#   'entailment'),
#  ("Two musicians are carrying speakers, guitars, and musical equipment. '[SEP]' The musicians are taking a math quiz.",
#   'contradiction'),
#  ("A skateboarder casts a shadow jumping down stairs. '[SEP]' A skateboarder crashed",
#   'contradiction'),
#  ("A man walking a gray poodle is walking past a billboard with a cow on it. '[SEP]' A man walking his pet past a billboard with a cow on it.",
#   'neutral'),
#  ("A little girl is swinging in her brightly colored swing outside. '[SEP]' The boy is swinging.",
#   'contradiction'),
#  ("Two men checking their barbecue in an oversized barbecue barrel. '[SEP]' Two men are sharing a barrel to barbecue pork.",
#   'neutral'),
#  ("Group of working man dressed in black and white laugh and talk on a cellphone. '[SEP]' Men laugh and take a break.",
#   'neutral'),
#  ("A man is singing into a microphone. '[SEP]' A man is reciting poetry.",
#   'contradiction'),
#  ("An older man with a large mustache talking into a bullhorn. '[SEP]' An older man with a large mustache happily talking",
#   'neutral'),
#  ("A man with a funny hat is dancing at a park. '[SEP]' girl sleeps alone",
#   'contradiction'),
#  ("Two guys at the beach playing in the sand, with one friend attempting to jump-kick the other. '[SEP]' The guys are at the beach.",
#   'entailment'),
#  ("Nadal celebrating, wearing a green headband '[SEP]' Someone totally naked.",
#   'contradiction'),
#  ("People with braided hair are gathered around. '[SEP]' The group of people are talking to each other.",
#   'neutral'),
#  ("A baby in a bouncy seat and a standing boy surrounded by toys. '[SEP]' Two siblings in the play room.",
#   'neutral'),
#  ("A man in a blue, plaid shirt in a garage wearing a protective mask and using a torch on his workbench. '[SEP]' The man is using a jackhammer.",
#   'contradiction'),
#  ("The men are having a pillow fight outside. '[SEP]' Men are having a pillow fight.",
#   'entailment'),
#  ("A man and women sitting on the floor and the guy is having a drink. '[SEP]' A man and a women sitting on the floor sharing a drink together indoors.",
#   'entailment'),
#  ("A lady in a gray sweater has a conversation with three other people at the same table. '[SEP]' A lady and three men are talking to each other at a table.",
#   'neutral'),
#  ("Man driving a red Coca-Cola truck by palm trees. '[SEP]' The person is waxing their vehicle.",
#   'contradiction'),
#  ("A man adjusts some materials in a pan. '[SEP]' A man walks through the florists.",
#   'contradiction'),
#  ('A man wearing a t-shirt that has "gnu" printed on it gives a technology presentation. \'[SEP]\' A man is giving a presentation at work.',
#   'entailment'),
#  ("a group of asian teenagers sitting in what looks like a waiting room with blue and red chairs, show off their electronic mini cameras. '[SEP]' Asian teenagers in a waiting room with blue and red chairs show each other their brand new electronic mini cameras.",
#   'neutral'),
#  ("Two little kids are beating on a bongo drum. '[SEP]' Two kids are playing with an instrument.",
#   'entailment'),
#  ("A man sitting on a gate looking at the water. '[SEP]' The man is getting ready to swim.",
#   'neutral'),
#  ("Cheerleaders in blue uniforms perform in the end zone of a football field. '[SEP]' the cheerleaders hand in toys and perform the football field",
#   'neutral'),
#  ("A man plays a keyboard and sings. '[SEP]' A singer rehearses a song with his keyboard.",
#   'neutral'),
#  ("Two people standing in front of vine covered wall with red flower overhead '[SEP]' Two people stand on an airplane.",
#   'contradiction'),
#  ("A man in a jean jacket is sleeping on the floor. '[SEP]' There is a man sleeping.",
#   'entailment'),
#  ("A group of people stand next to a wooden windmill swing in which two girls dressed in pink are sitting. '[SEP]' A family is having a reunion",
#   'neutral'),
#  ("A group of people enjoying themselves at an arcade. '[SEP]' A group of people playing.",
#   'entailment'),
#  ("A man in a blue kayak paddles in water. '[SEP]' A man is in a kayak.",
#   'entailment'),
#  ("Two bicyclists chat as they pass in front of a white building with columns. '[SEP]' The people are walking through the park.",
#   'contradiction'),
#  ("Sun drenched strollers enjoy music on the water. '[SEP]' People enjoy music at night.",
#   'contradiction'),
#  ("Two mounted policemen walk down a street. '[SEP]' Two policeman enter the bar.",
#   'contradiction'),
#  ("A weary man is finishing a race. '[SEP]' The man is in last place.",
#   'neutral'),
#  ("An older man is sitting in a lawn chair with a newspaper in his hand and selling paint cans, lawn chairs, and other items. '[SEP]' An old man has a newspaper.",
#   'entailment'),
#  ("A dog on an obstacle platform and a man. '[SEP]' A dog on an obstacle platform and a black man.",
#   'neutral'),
#  ("A group of people, some sitting and some standing, seem to be enjoying a sort of party, as there are streamers and balloons around them. '[SEP]' a group of people at a new years eve party",
#   'neutral'),
#  ("Three men are wearing safety yellow jackets and hard hats on the sight of a construction project; one is in a hole and the other two are looking at the man standing in the hole. '[SEP]' The construction workers are stopped for lunch.",
#   'contradiction'),
#  ("Three men playing golf close to the water. '[SEP]' Men playing golf close to the water.",
#   'entailment'),
#  ("A man in a blue shirt gesticulates as he speaks to a uniformed official. '[SEP]' A person is talking to a police officer.",
#   'neutral'),
#  ("Man holding a big sack with something inside, on his shoulder. '[SEP]' A man transports a heavy load.",
#   'neutral'),
#  ("A woman is getting her hair styled in a salon. '[SEP]' A woman is inside a salon.",
#   'entailment'),
#  ("A female diving into the cove on a sunny day. '[SEP]' A girl is going into the water.",
#   'entailment'),
#  ("Two motor-cross riders race through dirty snow. '[SEP]' Two motor-cross riders are outside.",
#   'entailment'),
#  ("A white dog is walking through the leafy grass while a brown dog is about to bite it. '[SEP]' The pets are sitting on a couch.",
#   'contradiction'),
#  ("A group of tourists aboard a small and colorful boat in the waters of a Southeast Asian country. '[SEP]' Tourists on a boat",
#   'entailment'),
#  ("A guy is standing on an ice patch by the sea, looking through a telescope at sunset. '[SEP]' a woman pilots a submarine on land",
#   'contradiction'),
#  ("Caucasian child wearing a red jacket, Standing near a tree. '[SEP]' A tree has lots of green leaves.",
#   'neutral'),
#  ("A group of people appear to be tilling the ground in front of a couple of thatch roof huts. '[SEP]' Preparing the soil for planting corn.",
#   'neutral'),
#  ("Three people are standing in front of a blue wall with graffiti on it, while three metal poles and three green crates are in the foreground. '[SEP]' People are standing near graffiti.",
#   'entailment'),
#  ("The lady in the red apron is preparing food for the up coming festivities. '[SEP]' A woman is dancing with her child.",
#   'contradiction'),
#  ("A man in a white t-shirt and blue jeans is attempting to sweep a dirty street. '[SEP]' A man sweeping a dirty street.",
#   'entailment'),
#  ("Three friends play with a dog in a lake. '[SEP]' Three family members play with a dog.",
#   'neutral'),
#  ("Woman in purple shirt stares into the distance. '[SEP]' The woman was looking at a menu",
#   'contradiction'),
#  ("One bear has fur that sticks up on its back resembling a mohawk. '[SEP]' The bear has wet fur.",
#   'neutral'),
#  ("all boys team pep meeting with mascot. '[SEP]' The girls volleyball game has just ended in a loss.",
#   'contradiction'),
#  ("A man about to kick a soccer ball. '[SEP]' A man takes a free kick in a recreational soccer game.",
#   'neutral'),
#  ("A man playing a saxaphone. '[SEP]' A man plays an instrument in a band.",
#   'neutral'),
#  ("A bald headed man in business casual attire is amused by something occurring off-screen- likely a comedic performance. '[SEP]' The man is wearing short pants and a muscle shirt.",
#   'contradiction'),
#  ("An elderly man sleeping on a bench on a pier. '[SEP]' An elder is on the bench",
#   'neutral'),
#  ("A band is playing in front of an audience and the singer is wearing an orange shirt and has tattoos on his arm. '[SEP]' A jukebox is playing music in front of an audience.",
#   'contradiction'),
#  ("Man in ring bending backwards with a bull behind him. '[SEP]' The man is a matador.",
#   'neutral'),
#  ("A woman wearing a green shirt is sliding down a purple slide. '[SEP]' She is near a playground",
#   'entailment'),
#  ("A watercraft speeds through the water. '[SEP]' The boat is really speeding on land.",
#   'contradiction'),
#  ("Four adults playing baseball, with a forest in the background. '[SEP]' With the desert in the background, four adults are telling stories about playing baseball.",
#   'contradiction'),
#  ("A man sitting, wearing a San Diego Padres hat plays on a keyboard. '[SEP]' A man is playing keyboard onstage.",
#   'neutral'),
#  ("Two motorcyclists racing neck and neck around a corner. '[SEP]' Two motorcyclists race to see who's motorcycle is faster.",
#   'neutral'),
#  ("A woman swinging a tennis racket on the court. '[SEP]' Two men are playing baseball.",
#   'contradiction'),
#  ("A steel worker on the job. '[SEP]' He is very tired.", 'neutral'),
#  ("Two foreign women, both wearing black, selling different types of foods. '[SEP]' Two women are selling food.",
#   'entailment'),
#  ("The surfer is in the wave. '[SEP]' a person is playing in water",
#   'entailment'),
#  ("A messy haired girl in a club. '[SEP]' A girl is looking for a date in a club.",
#   'neutral'),
#  ("A man leans against a statue in front of a building. '[SEP]' a man on leaning on a statue",
#   'entailment'),
#  ("A woman in blue shorts and a red and white striped shirt throws a soccer ball out onto a green field with players on it. '[SEP]' There are a players on the field.",
#   'entailment'),
#  ("a dog sitting in the grass, with his tongue out '[SEP]' A dog is outside.",
#   'entailment'),
#  ("Two boys are fooling around with pillows. '[SEP]' There is only one boy.",
#   'contradiction'),
#  ("Two men wearing work clothing climb a scaffold at a construction site. '[SEP]' Two men are working on construction.",
#   'entailment'),
#  ("Two clowns dressed in makeup and elaborate clothing stand together with their instruments. '[SEP]' Some mimes are on a street.",
#   'contradiction'),
#  ("A dog standing on a beach. '[SEP]' A dog is waiting for his master.",
#   'neutral'),
#  ("Three baseball players either playing a game or at a practice with one observer behind them. '[SEP]' There is a group of people playing football.",
#   'contradiction'),
#  ("A man pushes a child in a blue car while another child looks on. '[SEP]' The man is pushing a child.",
#   'entailment'),
#  ("A man is using a cutting board to chop food. '[SEP]' The man is near a cutting board.",
#   'entailment'),
#  ("Two dogs racing in a field, with people looking on. '[SEP]' The dogs are inside a house, looking out the window.",
#   'contradiction'),
#  ("There is a woman in a black jacket and sunglasses and a man in a white shirt with his back turned. '[SEP]' A dog is playing with a cat.",
#   'contradiction'),
#  ("A man in a white cowboy hat reclines in front of a window in an airport. '[SEP]' A man is wearing cowboy boots.",
#   'neutral'),
#  ("A man wearing a gray sweater walking through a pile of leaves. '[SEP]' The man is outside in the Fall.",
#   'neutral'),
#  ("A man sitting on a scooter on the curb. '[SEP]' A man is outside, near the street.",
#   'entailment'),
#  ("Two shirtless men are sparring while a line of men in white shirts and black shorts watch. '[SEP]' a group of people are watching two men fight.",
#   'entailment'),
#  ("An older man wearing a red western shirt and jeans sits in front of pieces of art. '[SEP]' A man is sitting in front of pieces of art.",
#   'entailment'),
#  ("A young man carries flags outside a building '[SEP]' The girl is running laps.",
#   'contradiction'),
#  ("A person with gray hair wears a red hat and watches it snow. '[SEP]' It is snowing.",
#   'entailment'),
#  ("A woman in a floral print blouse talks on her cellphone on the sidewalk. '[SEP]' A lady is talking on her cell phone.",
#   'entailment'),
#  ("A little girl opening a Christmas present. '[SEP]' The girl is little.",
#   'entailment'),
#  ("A man in a small rowboat traveling down a river surrounded by reeds and grasslands on both sides while seagulls fly in the air nearby. '[SEP]' A man is sleeping on the couch.",
#   'contradiction'),
#  ("A girl rides a unicycle as another rides a scooter next to her. '[SEP]' The girls are sitting in the tree house.",
#   'contradiction'),
#  ("A woman with glasses sitting at an inside table smiling at something with a glass of milk on the table in front of her. '[SEP]' The woman is indoors.",
#   'entailment'),
#  ("a little girl is playing in the hay. '[SEP]' A girl enjoys her time in a hay pile",
#   'entailment'),
#  ("A child is standing alone hear a pillar reading a book while pointing at the page. '[SEP]' A child is standing with his family.",
#   'contradiction'),
#  ("The person is dress from head to toe in white and is walking on the street. '[SEP]' Naked person laying on the street.",
#   'contradiction'),
#  ("Two people are sitting on the ground and one is holding a red plastic cup. '[SEP]' Two people are eating dinner.",
#   'contradiction'),
#  ("A boy looks startled as he falls in the sand. '[SEP]' A boy is scared, laying in the sand.",
#   'neutral'),
#  ("A man sits outside on a lawn chair using a hammer and chisel to shape a piece of wood. '[SEP]' A woman is walking in the park.",
#   'contradiction'),
#  ("A group of people stand on a stage and hold colorful buckets. '[SEP]' A large bucket holding several people.",
#   'contradiction'),
#  ("A man pulling a heavy cart full of bricks. '[SEP]' A man pulling a cart.",
#   'entailment'),
#  ("The couple pushed the strollers across the wood bridge and the dogs followed. '[SEP]' People and their pets cross the river on a bridge.",
#   'neutral'),
#  ("Peolple wearing Hawaiian shirts hold buckets by the water. '[SEP]' The people are friends.",
#   'neutral'),
#  ("Two children, a boy and girl jumping on a trampoline with a black protective net in a backyard full of trees. '[SEP]' The children are siblings playing.",
#   'neutral'),
#  ("One female healthcare provider is assisting a patient while the male healthcare provider is looking over information in a folder. '[SEP]' There is a folder.",
#   'entailment'),
#  ("An elderly woman sitting on a bench. '[SEP]' A grandmother waits on a bench.",
#   'neutral'),
#  ("The teddy bear has white pads on the bottom of its feet. '[SEP]' The teddy bear is giving me dirty looks.",
#   'contradiction'),
#  ("Woman wearing high heels falls on a cake. '[SEP]' Nobody is falling",
#   'contradiction'),
#  ("Two little boys reading and looking at books on the stairs. '[SEP]' Children have books to read inside.",
#   'entailment'),
#  ("A young lady turning away from camera. '[SEP]' A camera is turned on.",
#   'neutral'),
#  ("Three people are in an alley with a dumpster, one skateboarding over the dumpster while the other two look on. '[SEP]' Some of the people are professional skateboarders.",
#   'neutral')]

# %%
len(labeled_examples)
# Out:
# 506

# %%
len(unlabeled_examples)
# Out:
# 50055

# %%
len(test_examples)
# Out:
# 9824

# %% [markdown]
# Load the Tranformer Model

# %%
transformer = AutoModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %% [markdown]
# Functions required to convert examples into Dataloader

# %%
###################### generate data loader ganber pytorch origin
def generate_data_loader(input_examples, label_masks, label_map, do_shuffle = False, balance_label_examples = False):
  '''
  Generate a Dataloader given the input examples, eventually masked if they are
  to be considered NOT labeled.
  '''
  examples = []

  # Count the percentage of labeled examples
  num_labeled_examples = 0
  for label_mask in label_masks:
    if label_mask:
      num_labeled_examples += 1
  label_mask_rate = num_labeled_examples/len(input_examples)

  # if required it applies the balance
  for index, ex in enumerate(input_examples):
    if label_mask_rate == 1 or not balance_label_examples:
      examples.append((ex, label_masks[index]))
    else:
      # IT SIMULATE A LABELED EXAMPLE
      if label_masks[index]:
        balance = int(1/label_mask_rate)
        balance = int(math.log(balance,2))
        if balance < 1:
          balance = 1
        for b in range(0, int(balance)):
          examples.append((ex, label_masks[index]))
      else:
        examples.append((ex, label_masks[index]))

  #-----------------------------------------------
  # Generate input examples to the Transformer
  #-----------------------------------------------
  input_ids = []
  input_mask_array = []
  label_mask_array = []
  label_id_array = []

  # Tokenization
  for (text, label_mask) in examples:
    encoded_sent = tokenizer.encode(text[0], add_special_tokens=True, max_length=max_seq_length, padding="max_length", truncation=True)
    input_ids.append(encoded_sent)
    label_id_array.append(label_map[text[1]])
    label_mask_array.append(label_mask)

  # Attention to token (to ignore padded input wordpieces)
  for sent in input_ids:
    att_mask = [int(token_id > 0) for token_id in sent]
    input_mask_array.append(att_mask)
  # Convertion to Tensor
  input_ids = torch.tensor(input_ids)
  input_mask_array = torch.tensor(input_mask_array)
  label_id_array = torch.tensor(label_id_array, dtype=torch.long)
  label_mask_array = torch.tensor(label_mask_array)

  # Building the TensorDataset
  dataset = TensorDataset(input_ids, input_mask_array, label_id_array, label_mask_array)

  if do_shuffle:
    sampler = RandomSampler
  else:
    sampler = SequentialSampler

  # Building the DataLoader
  return DataLoader(
              dataset,  # The training samples.
              sampler = sampler(dataset),
              batch_size = batch_size) # Trains with this batch size.

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %% [markdown]
# Convert the input examples into DataLoader

# %%
label_map = {}
for (i, label) in enumerate(label_list):
  label_map[label] = i
#------------------------------
#   Load the train dataset
#------------------------------
train_examples = labeled_examples
#The labeled (train) dataset is assigned with a mask set to True
train_label_masks = np.ones(len(labeled_examples), dtype=bool)
#If unlabel examples are available
if unlabeled_examples:
  train_examples = train_examples + unlabeled_examples
  #The unlabeled (train) dataset is assigned with a mask set to False
  tmp_masks = np.zeros(len(unlabeled_examples), dtype=bool)
  train_label_masks = np.concatenate([train_label_masks,tmp_masks])

train_dataloader = generate_data_loader(train_examples, train_label_masks, label_map, do_shuffle = True, balance_label_examples = apply_balance)

#------------------------------
#   Load the test dataset
#------------------------------
#The labeled (test) dataset is assigned with a mask set to True
test_label_masks = np.ones(len(test_examples), dtype=bool)

test_dataloader = generate_data_loader(test_examples, test_label_masks, label_map, do_shuffle = False, balance_label_examples = False)
# Out:
# <ipython-input-23-bacb7df96025>:55: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   label_mask_array = torch.tensor(label_mask_array)

# %% [markdown]
# # We define the Generator and Discriminator

# %%
class Generator(nn.Module):
    def __init__(self, noise_size=100, output_size=512, hidden_sizes=[512], dropout_rate=0.1):
        super(Generator, self).__init__()
        layers = []
        hidden_sizes = [noise_size] + hidden_sizes
       # print(hidden_sizes)
        #print(len(hidden_sizes))
        for i in range(len(hidden_sizes)-1):
            layers.extend([nn.Linear(hidden_sizes[i], hidden_sizes[i+1]), nn.LeakyReLU(0.2, inplace=True), nn.Dropout(dropout_rate)])
            #print(i,layers)
        layers.append(nn.Linear(hidden_sizes[-1],output_size))
        self.layers = nn.Sequential(*layers)
        print(self.layers)
#nn.Sequential is an ordered container of modules. The data is passed through all the modules in the same order as defined.
    def forward(self, noise):
        output_rep = self.layers(noise)
        return output_rep

class Discriminator(nn.Module):
    def __init__(self, input_size=512, hidden_sizes=[512], num_labels=2, dropout_rate=0.1):
        super(Discriminator, self).__init__()
        self.input_dropout = nn.Dropout(p=dropout_rate)
        layers = []
        hidden_sizes = [input_size] + hidden_sizes
        for i in range(len(hidden_sizes)-1):
            layers.extend([nn.Linear(hidden_sizes[i], hidden_sizes[i+1]), nn.LeakyReLU(0.2, inplace=True), nn.Dropout(dropout_rate)])

        self.layers = nn.Sequential(*layers) #per il flatten
        self.logit = nn.Linear(hidden_sizes[-1],num_labels+1) # +1 for the probability of this sample being fake/real.
        #nn linear is a module which is used to create a single layer feed-forward network
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, input_rep):
        input_rep = self.input_dropout(input_rep)
        last_rep = self.layers(input_rep)
        #Logits simply means that the function operates on the unscaled output of earlier layers and that the relative scale to understand the units is linear. It means, in particular, the sum of the inputs may not equal 1
        logits = self.logit(last_rep)
        probs = self.softmax(logits)
        return last_rep, logits, probs

# %%
generator = Generator()
# Out:
# Sequential(
#   (0): Linear(in_features=100, out_features=512, bias=True)
#   (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=512, out_features=512, bias=True)
# )

# %% [markdown]
# We instantiate the Discriminator and Generator

# %%
# The config file is required to get the dimension of the vector produced by
# the underlying transformer
config = AutoConfig.from_pretrained(model_name)
hidden_size = int(config.hidden_size)
# Define the number and width of hidden layers
hidden_levels_g = [hidden_size for i in range(0, num_hidden_layers_g)]
hidden_levels_d = [hidden_size for i in range(0, num_hidden_layers_d)]

#-------------------------------------------------
#   Instantiate the Generator and Discriminator
#-------------------------------------------------
generator = Generator(noise_size=noise_size, output_size=hidden_size, hidden_sizes=hidden_levels_g, dropout_rate=out_dropout_rate)
discriminator = Discriminator(input_size=hidden_size, hidden_sizes=hidden_levels_d, num_labels=len(label_list), dropout_rate=out_dropout_rate)

# Put everything in the GPU if available
if torch.cuda.is_available():
  generator.cuda()
  discriminator.cuda()
  transformer.cuda()
  if multi_gpu:
    transformer = torch.nn.DataParallel(transformer)

# print(config)
# Out:
# Sequential(
#   (0): Linear(in_features=100, out_features=768, bias=True)
#   (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=768, out_features=768, bias=True)
# )

# %% [markdown]
# Let's go with the training procedure

# %%
training_stats = []

# Measure the total training time for the whole run.
total_t0 = time.time()

#models parameters
transformer_vars = [i for i in transformer.parameters()]
d_vars = transformer_vars + [v for v in discriminator.parameters()]
g_vars = [v for v in generator.parameters()]

#optimizer
dis_optimizer = torch.optim.AdamW(d_vars, lr=learning_rate_discriminator)
gen_optimizer = torch.optim.AdamW(g_vars, lr=learning_rate_generator)

#scheduler
if apply_scheduler:
  num_train_examples = len(train_examples)
  num_train_steps = int(num_train_examples / batch_size * num_train_epochs)
  num_warmup_steps = int(num_train_steps * warmup_proportion)

  scheduler_d = get_constant_schedule_with_warmup(dis_optimizer,
                                           num_warmup_steps = num_warmup_steps)
  scheduler_g = get_constant_schedule_with_warmup(gen_optimizer,
                                           num_warmup_steps = num_warmup_steps)

# Initialize empty lists to collect predictions and labels during training and testing
train_preds = []
train_labels = []
test_preds = []
test_labels = []

# For each epoch...
for epoch_i in range(0, num_train_epochs):
    # ========================================
    #               Training
    # ========================================
    # Perform one full pass over the training set.
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, num_train_epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    tr_g_loss = 0
    tr_d_loss = 0

    # Put the model into training mode.
    transformer.train()
    generator.train()
    discriminator.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every print_each_n_step batches.
        if step % print_each_n_step == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)

            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader.
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        b_label_mask = batch[3].to(device)

        real_batch_size = b_input_ids.shape[0]

        # Encode real data in the Transformer
        model_outputs = transformer(b_input_ids, attention_mask=b_input_mask)
        hidden_states = model_outputs[-1]

        # Generate fake data that should have the same distribution of the ones
        # encoded by the transformer.
        # First noisy input are used in input to the Generator
        noise = torch.zeros(real_batch_size, noise_size, device=device).uniform_(0, 1)
        # Gnerate Fake data
        gen_rep = generator(noise)

        # Generate the output of the Discriminator for real and fake data.
        # First, we put together the output of the tranformer and the generator
        disciminator_input = torch.cat([hidden_states, gen_rep], dim=0)
        # Then, we select the output of the disciminator
        features, logits, probs = discriminator(disciminator_input)

        # Finally, we separate the discriminator's output for the real and fake
        # data
        features_list = torch.split(features, real_batch_size)
        D_real_features = features_list[0]
        D_fake_features = features_list[1]

        logits_list = torch.split(logits, real_batch_size)
        D_real_logits = logits_list[0]
        D_fake_logits = logits_list[1]

        probs_list = torch.split(probs, real_batch_size)
        D_real_probs = probs_list[0]
        D_fake_probs = probs_list[1]

        # Get predictions from logits (replace this with your model's output)
        _, preds = torch.max(logits, 1)  # This line assumes a classification task
        # If your model output differs, adjust how you obtain predictions

        train_preds += preds.detach().cpu().tolist()  # Collect predictions
        train_labels += b_labels.detach().cpu().tolist()  # Collect labels

        #---------------------------------
        #  LOSS evaluation
        #---------------------------------
        # Generator's LOSS estimation
        g_loss_d = -1 * torch.mean(torch.log(1 - D_fake_probs[:,-1] + epsilon))
        g_feat_reg = torch.mean(torch.pow(torch.mean(D_real_features, dim=0) - torch.mean(D_fake_features, dim=0), 2))
        g_loss = g_loss_d + g_feat_reg

        # Disciminator's LOSS estimation
        logits = D_real_logits[:,0:-1]
        log_probs = F.log_softmax(logits, dim=-1)
        # The discriminator provides an output for labeled and unlabeled real data
        # so the loss evaluated for unlabeled data is ignored (masked)
        label2one_hot = torch.nn.functional.one_hot(b_labels, len(label_list))
        per_example_loss = -torch.sum(label2one_hot * log_probs, dim=-1)
        per_example_loss = torch.masked_select(per_example_loss, b_label_mask.to(device))
        labeled_example_count = per_example_loss.type(torch.float32).numel()

        # It may be the case that a batch does not contain labeled examples,
        # so the "supervised loss" in this case is not evaluated
        if labeled_example_count == 0:
          D_L_Supervised = 0
        else:
          D_L_Supervised = torch.div(torch.sum(per_example_loss.to(device)), labeled_example_count)

        D_L_unsupervised1U = -1 * torch.mean(torch.log(1 - D_real_probs[:, -1] + epsilon))
        D_L_unsupervised2U = -1 * torch.mean(torch.log(D_fake_probs[:, -1] + epsilon))
        d_loss = D_L_Supervised + D_L_unsupervised1U + D_L_unsupervised2U

        #---------------------------------
        #  OPTIMIZATION
        #---------------------------------
        # Avoid gradient accumulation
        gen_optimizer.zero_grad()
        dis_optimizer.zero_grad()

        # Calculate weigth updates
        # retain_graph=True is required since the underlying graph will be deleted after backward
        g_loss.backward(retain_graph=True)
        d_loss.backward()

        # Apply modifications
        gen_optimizer.step()
        dis_optimizer.step()

        # A detail log of the individual losses
        #print("{0:.4f}\t{1:.4f}\t{2:.4f}\t{3:.4f}\t{4:.4f}".
        #      format(D_L_Supervised, D_L_unsupervised1U, D_L_unsupervised2U,
        #             g_loss_d, g_feat_reg))

        # Save the losses to print them later
        tr_g_loss += g_loss.item()
        tr_d_loss += d_loss.item()

        # Update the learning rate with the scheduler
        if apply_scheduler:
          scheduler_d.step()
          scheduler_g.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss_g = tr_g_loss / len(train_dataloader)
    avg_train_loss_d = tr_d_loss / len(train_dataloader)

    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss generetor: {0:.3f}".format(avg_train_loss_g))
    print("  Average training loss discriminator: {0:.3f}".format(avg_train_loss_d))
    print("  Training epcoh took: {:}".format(training_time))

    # ========================================
    #     TEST ON THE EVALUATION DATASET
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our test set.
    print("")
    print("Running Test...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    transformer.eval() #maybe redundant
    discriminator.eval()
    generator.eval()

    # Tracking variables
    total_test_accuracy = 0

    total_test_loss = 0
    nb_test_steps = 0

    all_preds = []
    all_labels_ids = []

    #loss
    nll_loss = torch.nn.CrossEntropyLoss(ignore_index=-1)

    # Evaluate data for one epoch
    for batch in test_dataloader:

        # Unpack this training batch from our dataloader.
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():
            model_outputs = transformer(b_input_ids, attention_mask=b_input_mask)
            hidden_states = model_outputs[-1]
            _, logits, probs = discriminator(hidden_states)
            ###log_probs = F.log_softmax(probs[:,1:], dim=-1)
            filtered_logits = logits[:,0:-1]
            # Accumulate the test loss.
            total_test_loss += nll_loss(filtered_logits, b_labels)

        # Accumulate the predictions and the input labels
        _, preds = torch.max(filtered_logits, 1)
        all_preds += preds.detach().cpu()
        all_labels_ids += b_labels.detach().cpu()
        test_preds += preds.detach().cpu().tolist()  # Collect predictions
        test_labels += b_labels.detach().cpu().tolist()  # Collect labels

    # Report the final accuracy for this validation run.
    all_preds = torch.stack(all_preds).numpy()
    all_labels_ids = torch.stack(all_labels_ids).numpy()
    test_accuracy = np.sum(all_preds == all_labels_ids) / len(all_preds)
    print("  Accuracy: {0:.3f}".format(test_accuracy))

    # Calculate the average loss over all of the batches.
    avg_test_loss = total_test_loss / len(test_dataloader)
    avg_test_loss = avg_test_loss.item()

    # Measure how long the validation run took.
    test_time = format_time(time.time() - t0)

    print("  Test Loss: {0:.3f}".format(avg_test_loss))
    print("  Test took: {:}".format(test_time))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss generator': avg_train_loss_g,
            'Training Loss discriminator': avg_train_loss_d,
            'Valid. Loss': avg_test_loss,
            'Valid. Accur.': test_accuracy,
            'Training Time': training_time,
            'Test Time': test_time
        }
    )

    # # After the loops, calculate F1-score and accuracy for training set
    # train_f1 = f1_score(train_labels, train_preds, average='weighted')
    # train_acc = accuracy_score(train_labels, train_preds)

    # # Calculate F1-score and accuracy for test set
    # test_f1 = f1_score(test_labels, test_preds, average='weighted')
    # test_acc = accuracy_score(test_labels, test_preds)

    # # Print F1-score and accuracy for training and test sets
    # print("Training set:")
    # print(f"  F1-score: {train_f1:.4f}")
    # print(f"  Accuracy: {train_acc:.4f}")

    # print("\nTest set:")
    # print(f"  F1-score: {test_f1:.4f}")
    # print(f"  Accuracy: {test_acc:.4f}")
# Out:
# ======== Epoch 1 / 1 ========
# Training...
#   Batch    10  of  6,637.    Elapsed: 0:00:04.
#   Batch    20  of  6,637.    Elapsed: 0:00:05.
#   Batch    30  of  6,637.    Elapsed: 0:00:06.
#   Batch    40  of  6,637.    Elapsed: 0:00:07.
#   Batch    50  of  6,637.    Elapsed: 0:00:08.
#   Batch    60  of  6,637.    Elapsed: 0:00:10.
#   Batch    70  of  6,637.    Elapsed: 0:00:11.
#   Batch    80  of  6,637.    Elapsed: 0:00:12.
#   Batch    90  of  6,637.    Elapsed: 0:00:13.
#   Batch   100  of  6,637.    Elapsed: 0:00:14.
#   Batch   110  of  6,637.    Elapsed: 0:00:15.
#   Batch   120  of  6,637.    Elapsed: 0:00:16.
#   Batch   130  of  6,637.    Elapsed: 0:00:17.
#   Batch   140  of  6,637.    Elapsed: 0:00:18.
#   Batch   150  of  6,637.    Elapsed: 0:00:19.
#   Batch   160  of  6,637.    Elapsed: 0:00:20.
#   Batch   170  of  6,637.    Elapsed: 0:00:21.
#   Batch   180  of  6,637.    Elapsed: 0:00:22.
#   Batch   190  of  6,637.    Elapsed: 0:00:23.
#   Batch   200  of  6,637.    Elapsed: 0:00:25.
#   Batch   210  of  6,637.    Elapsed: 0:00:26.
#   Batch   220  of  6,637.    Elapsed: 0:00:27.
#   Batch   230  of  6,637.    Elapsed: 0:00:28.
#   Batch   240  of  6,637.    Elapsed: 0:00:29.
#   Batch   250  of  6,637.    Elapsed: 0:00:30.
#   Batch   260  of  6,637.    Elapsed: 0:00:31.
#   Batch   270  of  6,637.    Elapsed: 0:00:32.
#   Batch   280  of  6,637.    Elapsed: 0:00:33.
#   Batch   290  of  6,637.    Elapsed: 0:00:34.
#   Batch   300  of  6,637.    Elapsed: 0:00:35.
#   Batch   310  of  6,637.    Elapsed: 0:00:36.
#   Batch   320  of  6,637.    Elapsed: 0:00:37.
#   Batch   330  of  6,637.    Elapsed: 0:00:38.
#   Batch   340  of  6,637.    Elapsed: 0:00:39.
#   Batch   350  of  6,637.    Elapsed: 0:00:41.
#   Batch   360  of  6,637.    Elapsed: 0:00:42.
#   Batch   370  of  6,637.    Elapsed: 0:00:43.
#   Batch   380  of  6,637.    Elapsed: 0:00:44.
#   Batch   390  of  6,637.    Elapsed: 0:00:45.
#   Batch   400  of  6,637.    Elapsed: 0:00:46.
#   Batch   410  of  6,637.    Elapsed: 0:00:47.
#   Batch   420  of  6,637.    Elapsed: 0:00:49.
#   Batch   430  of  6,637.    Elapsed: 0:00:50.
#   Batch   440  of  6,637.    Elapsed: 0:00:51.
#   Batch   450  of  6,637.    Elapsed: 0:00:53.
#   Batch   460  of  6,637.    Elapsed: 0:00:55.
#   Batch   470  of  6,637.    Elapsed: 0:00:57.
#   Batch   480  of  6,637.    Elapsed: 0:00:59.
#   Batch   490  of  6,637.    Elapsed: 0:01:00.
#   Batch   500  of  6,637.    Elapsed: 0:01:02.
#   Batch   510  of  6,637.    Elapsed: 0:01:03.
#   Batch   520  of  6,637.    Elapsed: 0:01:04.
#   Batch   530  of  6,637.    Elapsed: 0:01:05.
#   Batch   540  of  6,637.    Elapsed: 0:01:07.
#   Batch   550  of  6,637.    Elapsed: 0:01:08.
#   Batch   560  of  6,637.    Elapsed: 0:01:09.
#   Batch   570  of  6,637.    Elapsed: 0:01:10.
#   Batch   580  of  6,637.    Elapsed: 0:01:11.
#   Batch   590  of  6,637.    Elapsed: 0:01:12.
#   Batch   600  of  6,637.    Elapsed: 0:01:13.
#   Batch   610  of  6,637.    Elapsed: 0:01:14.
#   Batch   620  of  6,637.    Elapsed: 0:01:15.
#   Batch   630  of  6,637.    Elapsed: 0:01:17.
#   Batch   640  of  6,637.    Elapsed: 0:01:18.
#   Batch   650  of  6,637.    Elapsed: 0:01:19.
#   Batch   660  of  6,637.    Elapsed: 0:01:20.
#   Batch   670  of  6,637.    Elapsed: 0:01:21.
#   Batch   680  of  6,637.    Elapsed: 0:01:22.
#   Batch   690  of  6,637.    Elapsed: 0:01:23.
#   Batch   700  of  6,637.    Elapsed: 0:01:24.
#   Batch   710  of  6,637.    Elapsed: 0:01:25.
#   Batch   720  of  6,637.    Elapsed: 0:01:26.
#   Batch   730  of  6,637.    Elapsed: 0:01:27.
#   Batch   740  of  6,637.    Elapsed: 0:01:28.
#   Batch   750  of  6,637.    Elapsed: 0:01:30.
#   Batch   760  of  6,637.    Elapsed: 0:01:31.
#   Batch   770  of  6,637.    Elapsed: 0:01:32.
#   Batch   780  of  6,637.    Elapsed: 0:01:33.
#   Batch   790  of  6,637.    Elapsed: 0:01:34.
#   Batch   800  of  6,637.    Elapsed: 0:01:35.
#   Batch   810  of  6,637.    Elapsed: 0:01:36.
#   Batch   820  of  6,637.    Elapsed: 0:01:37.
#   Batch   830  of  6,637.    Elapsed: 0:01:38.
#   Batch   840  of  6,637.    Elapsed: 0:01:39.
#   Batch   850  of  6,637.    Elapsed: 0:01:40.
#   Batch   860  of  6,637.    Elapsed: 0:01:41.
#   Batch   870  of  6,637.    Elapsed: 0:01:42.
#   Batch   880  of  6,637.    Elapsed: 0:01:43.
#   Batch   890  of  6,637.    Elapsed: 0:01:45.
#   Batch   900  of  6,637.    Elapsed: 0:01:46.
#   Batch   910  of  6,637.    Elapsed: 0:01:47.
#   Batch   920  of  6,637.    Elapsed: 0:01:48.
#   Batch   930  of  6,637.    Elapsed: 0:01:49.
#   Batch   940  of  6,637.    Elapsed: 0:01:50.
#   Batch   950  of  6,637.    Elapsed: 0:01:51.
#   Batch   960  of  6,637.    Elapsed: 0:01:52.
#   Batch   970  of  6,637.    Elapsed: 0:01:53.
#   Batch   980  of  6,637.    Elapsed: 0:01:54.
#   Batch   990  of  6,637.    Elapsed: 0:01:55.
#   Batch 1,000  of  6,637.    Elapsed: 0:01:56.
#   Batch 1,010  of  6,637.    Elapsed: 0:01:57.
#   Batch 1,020  of  6,637.    Elapsed: 0:01:58.
#   Batch 1,030  of  6,637.    Elapsed: 0:02:00.
#   Batch 1,040  of  6,637.    Elapsed: 0:02:01.
#   Batch 1,050  of  6,637.    Elapsed: 0:02:02.
#   Batch 1,060  of  6,637.    Elapsed: 0:02:03.
#   Batch 1,070  of  6,637.    Elapsed: 0:02:04.
#   Batch 1,080  of  6,637.    Elapsed: 0:02:05.
#   Batch 1,090  of  6,637.    Elapsed: 0:02:06.
#   Batch 1,100  of  6,637.    Elapsed: 0:02:07.
#   Batch 1,110  of  6,637.    Elapsed: 0:02:08.
#   Batch 1,120  of  6,637.    Elapsed: 0:02:09.
#   Batch 1,130  of  6,637.    Elapsed: 0:02:10.
#   Batch 1,140  of  6,637.    Elapsed: 0:02:12.
#   Batch 1,150  of  6,637.    Elapsed: 0:02:13.
#   Batch 1,160  of  6,637.    Elapsed: 0:02:14.
#   Batch 1,170  of  6,637.    Elapsed: 0:02:15.
#   Batch 1,180  of  6,637.    Elapsed: 0:02:17.
#   Batch 1,190  of  6,637.    Elapsed: 0:02:18.
#   Batch 1,200  of  6,637.    Elapsed: 0:02:19.
#   Batch 1,210  of  6,637.    Elapsed: 0:02:20.
#   Batch 1,220  of  6,637.    Elapsed: 0:02:21.
#   Batch 1,230  of  6,637.    Elapsed: 0:02:22.
#   Batch 1,240  of  6,637.    Elapsed: 0:02:23.
#   Batch 1,250  of  6,637.    Elapsed: 0:02:24.
#   Batch 1,260  of  6,637.    Elapsed: 0:02:25.
#   Batch 1,270  of  6,637.    Elapsed: 0:02:26.
#   Batch 1,280  of  6,637.    Elapsed: 0:02:27.
#   Batch 1,290  of  6,637.    Elapsed: 0:02:28.
#   Batch 1,300  of  6,637.    Elapsed: 0:02:29.
#   Batch 1,310  of  6,637.    Elapsed: 0:02:30.
#   Batch 1,320  of  6,637.    Elapsed: 0:02:32.
#   Batch 1,330  of  6,637.    Elapsed: 0:02:33.
#   Batch 1,340  of  6,637.    Elapsed: 0:02:34.
#   Batch 1,350  of  6,637.    Elapsed: 0:02:35.
#   Batch 1,360  of  6,637.    Elapsed: 0:02:36.
#   Batch 1,370  of  6,637.    Elapsed: 0:02:37.
#   Batch 1,380  of  6,637.    Elapsed: 0:02:38.
#   Batch 1,390  of  6,637.    Elapsed: 0:02:39.
#   Batch 1,400  of  6,637.    Elapsed: 0:02:40.
#   Batch 1,410  of  6,637.    Elapsed: 0:02:41.
#   Batch 1,420  of  6,637.    Elapsed: 0:02:42.
#   Batch 1,430  of  6,637.    Elapsed: 0:02:43.
#   Batch 1,440  of  6,637.    Elapsed: 0:02:44.
#   Batch 1,450  of  6,637.    Elapsed: 0:02:45.
#   Batch 1,460  of  6,637.    Elapsed: 0:02:47.
#   Batch 1,470  of  6,637.    Elapsed: 0:02:48.
#   Batch 1,480  of  6,637.    Elapsed: 0:02:49.
#   Batch 1,490  of  6,637.    Elapsed: 0:02:50.
#   Batch 1,500  of  6,637.    Elapsed: 0:02:51.
#   Batch 1,510  of  6,637.    Elapsed: 0:02:52.
#   Batch 1,520  of  6,637.    Elapsed: 0:02:53.
#   Batch 1,530  of  6,637.    Elapsed: 0:02:54.
#   Batch 1,540  of  6,637.    Elapsed: 0:02:55.
#   Batch 1,550  of  6,637.    Elapsed: 0:02:56.
#   Batch 1,560  of  6,637.    Elapsed: 0:02:57.
#   Batch 1,570  of  6,637.    Elapsed: 0:02:58.
#   Batch 1,580  of  6,637.    Elapsed: 0:03:00.
#   Batch 1,590  of  6,637.    Elapsed: 0:03:01.
#   Batch 1,600  of  6,637.    Elapsed: 0:03:02.
#   Batch 1,610  of  6,637.    Elapsed: 0:03:03.
#   Batch 1,620  of  6,637.    Elapsed: 0:03:04.
#   Batch 1,630  of  6,637.    Elapsed: 0:03:05.
#   Batch 1,640  of  6,637.    Elapsed: 0:03:06.
#   Batch 1,650  of  6,637.    Elapsed: 0:03:07.
#   Batch 1,660  of  6,637.    Elapsed: 0:03:08.
#   Batch 1,670  of  6,637.    Elapsed: 0:03:09.
#   Batch 1,680  of  6,637.    Elapsed: 0:03:10.
#   Batch 1,690  of  6,637.    Elapsed: 0:03:11.
#   Batch 1,700  of  6,637.    Elapsed: 0:03:13.
#   Batch 1,710  of  6,637.    Elapsed: 0:03:14.
#   Batch 1,720  of  6,637.    Elapsed: 0:03:15.
#   Batch 1,730  of  6,637.    Elapsed: 0:03:16.
#   Batch 1,740  of  6,637.    Elapsed: 0:03:17.
#   Batch 1,750  of  6,637.    Elapsed: 0:03:18.
#   Batch 1,760  of  6,637.    Elapsed: 0:03:19.
#   Batch 1,770  of  6,637.    Elapsed: 0:03:20.
#   Batch 1,780  of  6,637.    Elapsed: 0:03:21.
#   Batch 1,790  of  6,637.    Elapsed: 0:03:22.
#   Batch 1,800  of  6,637.    Elapsed: 0:03:23.
#   Batch 1,810  of  6,637.    Elapsed: 0:03:25.
#   Batch 1,820  of  6,637.    Elapsed: 0:03:26.
#   Batch 1,830  of  6,637.    Elapsed: 0:03:27.
#   Batch 1,840  of  6,637.    Elapsed: 0:03:28.
#   Batch 1,850  of  6,637.    Elapsed: 0:03:29.
#   Batch 1,860  of  6,637.    Elapsed: 0:03:30.
#   Batch 1,870  of  6,637.    Elapsed: 0:03:31.
#   Batch 1,880  of  6,637.    Elapsed: 0:03:32.
#   Batch 1,890  of  6,637.    Elapsed: 0:03:33.
#   Batch 1,900  of  6,637.    Elapsed: 0:03:34.
#   Batch 1,910  of  6,637.    Elapsed: 0:03:35.
#   Batch 1,920  of  6,637.    Elapsed: 0:03:36.
#   Batch 1,930  of  6,637.    Elapsed: 0:03:37.
#   Batch 1,940  of  6,637.    Elapsed: 0:03:39.
#   Batch 1,950  of  6,637.    Elapsed: 0:03:40.
#   Batch 1,960  of  6,637.    Elapsed: 0:03:41.
#   Batch 1,970  of  6,637.    Elapsed: 0:03:42.
#   Batch 1,980  of  6,637.    Elapsed: 0:03:43.
#   Batch 1,990  of  6,637.    Elapsed: 0:03:44.
#   Batch 2,000  of  6,637.    Elapsed: 0:03:45.
#   Batch 2,010  of  6,637.    Elapsed: 0:03:46.
#   Batch 2,020  of  6,637.    Elapsed: 0:03:47.
#   Batch 2,030  of  6,637.    Elapsed: 0:03:48.
#   Batch 2,040  of  6,637.    Elapsed: 0:03:49.
#   Batch 2,050  of  6,637.    Elapsed: 0:03:50.
#   Batch 2,060  of  6,637.    Elapsed: 0:03:51.
#   Batch 2,070  of  6,637.    Elapsed: 0:03:53.
#   Batch 2,080  of  6,637.    Elapsed: 0:03:54.
#   Batch 2,090  of  6,637.    Elapsed: 0:03:55.
#   Batch 2,100  of  6,637.    Elapsed: 0:03:56.
#   Batch 2,110  of  6,637.    Elapsed: 0:03:57.
#   Batch 2,120  of  6,637.    Elapsed: 0:03:58.
#   Batch 2,130  of  6,637.    Elapsed: 0:03:59.
#   Batch 2,140  of  6,637.    Elapsed: 0:04:00.
#   Batch 2,150  of  6,637.    Elapsed: 0:04:01.
#   Batch 2,160  of  6,637.    Elapsed: 0:04:02.
#   Batch 2,170  of  6,637.    Elapsed: 0:04:03.
#   Batch 2,180  of  6,637.    Elapsed: 0:04:04.
#   Batch 2,190  of  6,637.    Elapsed: 0:04:05.
#   Batch 2,200  of  6,637.    Elapsed: 0:04:06.
#   Batch 2,210  of  6,637.    Elapsed: 0:04:08.
#   Batch 2,220  of  6,637.    Elapsed: 0:04:09.
#   Batch 2,230  of  6,637.    Elapsed: 0:04:10.
#   Batch 2,240  of  6,637.    Elapsed: 0:04:11.
#   Batch 2,250  of  6,637.    Elapsed: 0:04:12.
#   Batch 2,260  of  6,637.    Elapsed: 0:04:13.
#   Batch 2,270  of  6,637.    Elapsed: 0:04:14.
#   Batch 2,280  of  6,637.    Elapsed: 0:04:15.
#   Batch 2,290  of  6,637.    Elapsed: 0:04:16.
#   Batch 2,300  of  6,637.    Elapsed: 0:04:17.
#   Batch 2,310  of  6,637.    Elapsed: 0:04:18.
#   Batch 2,320  of  6,637.    Elapsed: 0:04:19.
#   Batch 2,330  of  6,637.    Elapsed: 0:04:20.
#   Batch 2,340  of  6,637.    Elapsed: 0:04:22.
#   Batch 2,350  of  6,637.    Elapsed: 0:04:23.
#   Batch 2,360  of  6,637.    Elapsed: 0:04:24.
#   Batch 2,370  of  6,637.    Elapsed: 0:04:25.
#   Batch 2,380  of  6,637.    Elapsed: 0:04:26.
#   Batch 2,390  of  6,637.    Elapsed: 0:04:27.
#   Batch 2,400  of  6,637.    Elapsed: 0:04:28.
#   Batch 2,410  of  6,637.    Elapsed: 0:04:29.
#   Batch 2,420  of  6,637.    Elapsed: 0:04:30.
#   Batch 2,430  of  6,637.    Elapsed: 0:04:31.
#   Batch 2,440  of  6,637.    Elapsed: 0:04:32.
#   Batch 2,450  of  6,637.    Elapsed: 0:04:34.
#   Batch 2,460  of  6,637.    Elapsed: 0:04:35.
#   Batch 2,470  of  6,637.    Elapsed: 0:04:36.
#   Batch 2,480  of  6,637.    Elapsed: 0:04:37.
#   Batch 2,490  of  6,637.    Elapsed: 0:04:38.
#   Batch 2,500  of  6,637.    Elapsed: 0:04:39.
#   Batch 2,510  of  6,637.    Elapsed: 0:04:40.
#   Batch 2,520  of  6,637.    Elapsed: 0:04:41.
#   Batch 2,530  of  6,637.    Elapsed: 0:04:42.
#   Batch 2,540  of  6,637.    Elapsed: 0:04:43.
#   Batch 2,550  of  6,637.    Elapsed: 0:04:44.
#   Batch 2,560  of  6,637.    Elapsed: 0:04:45.
#   Batch 2,570  of  6,637.    Elapsed: 0:04:47.
#   Batch 2,580  of  6,637.    Elapsed: 0:04:48.
#   Batch 2,590  of  6,637.    Elapsed: 0:04:49.
#   Batch 2,600  of  6,637.    Elapsed: 0:04:50.
#   Batch 2,610  of  6,637.    Elapsed: 0:04:51.
#   Batch 2,620  of  6,637.    Elapsed: 0:04:52.
#   Batch 2,630  of  6,637.    Elapsed: 0:04:53.
#   Batch 2,640  of  6,637.    Elapsed: 0:04:54.
#   Batch 2,650  of  6,637.    Elapsed: 0:04:55.
#   Batch 2,660  of  6,637.    Elapsed: 0:04:56.
#   Batch 2,670  of  6,637.    Elapsed: 0:04:57.
#   Batch 2,680  of  6,637.    Elapsed: 0:04:58.
#   Batch 2,690  of  6,637.    Elapsed: 0:05:00.
#   Batch 2,700  of  6,637.    Elapsed: 0:05:01.
#   Batch 2,710  of  6,637.    Elapsed: 0:05:02.
#   Batch 2,720  of  6,637.    Elapsed: 0:05:03.
#   Batch 2,730  of  6,637.    Elapsed: 0:05:04.
#   Batch 2,740  of  6,637.    Elapsed: 0:05:05.
#   Batch 2,750  of  6,637.    Elapsed: 0:05:06.
#   Batch 2,760  of  6,637.    Elapsed: 0:05:07.
#   Batch 2,770  of  6,637.    Elapsed: 0:05:08.
#   Batch 2,780  of  6,637.    Elapsed: 0:05:09.
#   Batch 2,790  of  6,637.    Elapsed: 0:05:10.
#   Batch 2,800  of  6,637.    Elapsed: 0:05:11.
#   Batch 2,810  of  6,637.    Elapsed: 0:05:12.
#   Batch 2,820  of  6,637.    Elapsed: 0:05:14.
#   Batch 2,830  of  6,637.    Elapsed: 0:05:15.
#   Batch 2,840  of  6,637.    Elapsed: 0:05:16.
#   Batch 2,850  of  6,637.    Elapsed: 0:05:17.
#   Batch 2,860  of  6,637.    Elapsed: 0:05:18.
#   Batch 2,870  of  6,637.    Elapsed: 0:05:19.
#   Batch 2,880  of  6,637.    Elapsed: 0:05:20.
#   Batch 2,890  of  6,637.    Elapsed: 0:05:21.
#   Batch 2,900  of  6,637.    Elapsed: 0:05:22.
#   Batch 2,910  of  6,637.    Elapsed: 0:05:23.
#   Batch 2,920  of  6,637.    Elapsed: 0:05:24.
#   Batch 2,930  of  6,637.    Elapsed: 0:05:25.
#   Batch 2,940  of  6,637.    Elapsed: 0:05:26.
#   Batch 2,950  of  6,637.    Elapsed: 0:05:27.
#   Batch 2,960  of  6,637.    Elapsed: 0:05:29.
#   Batch 2,970  of  6,637.    Elapsed: 0:05:30.
#   Batch 2,980  of  6,637.    Elapsed: 0:05:31.
#   Batch 2,990  of  6,637.    Elapsed: 0:05:32.
#   Batch 3,000  of  6,637.    Elapsed: 0:05:33.
#   Batch 3,010  of  6,637.    Elapsed: 0:05:34.
#   Batch 3,020  of  6,637.    Elapsed: 0:05:35.
#   Batch 3,030  of  6,637.    Elapsed: 0:05:36.
#   Batch 3,040  of  6,637.    Elapsed: 0:05:37.
#   Batch 3,050  of  6,637.    Elapsed: 0:05:38.
#   Batch 3,060  of  6,637.    Elapsed: 0:05:39.
#   Batch 3,070  of  6,637.    Elapsed: 0:05:40.
#   Batch 3,080  of  6,637.    Elapsed: 0:05:41.
#   Batch 3,090  of  6,637.    Elapsed: 0:05:43.
#   Batch 3,100  of  6,637.    Elapsed: 0:05:44.
#   Batch 3,110  of  6,637.    Elapsed: 0:05:45.
#   Batch 3,120  of  6,637.    Elapsed: 0:05:46.
#   Batch 3,130  of  6,637.    Elapsed: 0:05:47.
#   Batch 3,140  of  6,637.    Elapsed: 0:05:48.
#   Batch 3,150  of  6,637.    Elapsed: 0:05:49.
#   Batch 3,160  of  6,637.    Elapsed: 0:05:50.
#   Batch 3,170  of  6,637.    Elapsed: 0:05:51.
#   Batch 3,180  of  6,637.    Elapsed: 0:05:52.
#   Batch 3,190  of  6,637.    Elapsed: 0:05:53.
#   Batch 3,200  of  6,637.    Elapsed: 0:05:54.
#   Batch 3,210  of  6,637.    Elapsed: 0:05:55.
#   Batch 3,220  of  6,637.    Elapsed: 0:05:56.
#   Batch 3,230  of  6,637.    Elapsed: 0:05:58.
#   Batch 3,240  of  6,637.    Elapsed: 0:05:59.
#   Batch 3,250  of  6,637.    Elapsed: 0:06:00.
#   Batch 3,260  of  6,637.    Elapsed: 0:06:01.
#   Batch 3,270  of  6,637.    Elapsed: 0:06:02.
#   Batch 3,280  of  6,637.    Elapsed: 0:06:03.
#   Batch 3,290  of  6,637.    Elapsed: 0:06:04.
#   Batch 3,300  of  6,637.    Elapsed: 0:06:05.
#   Batch 3,310  of  6,637.    Elapsed: 0:06:06.
#   Batch 3,320  of  6,637.    Elapsed: 0:06:07.
#   Batch 3,330  of  6,637.    Elapsed: 0:06:08.
#   Batch 3,340  of  6,637.    Elapsed: 0:06:09.
#   Batch 3,350  of  6,637.    Elapsed: 0:06:10.
#   Batch 3,360  of  6,637.    Elapsed: 0:06:11.
#   Batch 3,370  of  6,637.    Elapsed: 0:06:12.
#   Batch 3,380  of  6,637.    Elapsed: 0:06:14.
#   Batch 3,390  of  6,637.    Elapsed: 0:06:15.
#   Batch 3,400  of  6,637.    Elapsed: 0:06:16.
#   Batch 3,410  of  6,637.    Elapsed: 0:06:17.
#   Batch 3,420  of  6,637.    Elapsed: 0:06:18.
#   Batch 3,430  of  6,637.    Elapsed: 0:06:19.
#   Batch 3,440  of  6,637.    Elapsed: 0:06:20.
#   Batch 3,450  of  6,637.    Elapsed: 0:06:21.
#   Batch 3,460  of  6,637.    Elapsed: 0:06:22.
#   Batch 3,470  of  6,637.    Elapsed: 0:06:23.
#   Batch 3,480  of  6,637.    Elapsed: 0:06:24.
#   Batch 3,490  of  6,637.    Elapsed: 0:06:25.
#   Batch 3,500  of  6,637.    Elapsed: 0:06:26.
#   Batch 3,510  of  6,637.    Elapsed: 0:06:28.
#   Batch 3,520  of  6,637.    Elapsed: 0:06:29.
#   Batch 3,530  of  6,637.    Elapsed: 0:06:30.
#   Batch 3,540  of  6,637.    Elapsed: 0:06:31.
#   Batch 3,550  of  6,637.    Elapsed: 0:06:32.
#   Batch 3,560  of  6,637.    Elapsed: 0:06:33.
#   Batch 3,570  of  6,637.    Elapsed: 0:06:34.
#   Batch 3,580  of  6,637.    Elapsed: 0:06:35.
#   Batch 3,590  of  6,637.    Elapsed: 0:06:36.
#   Batch 3,600  of  6,637.    Elapsed: 0:06:37.
#   Batch 3,610  of  6,637.    Elapsed: 0:06:38.
#   Batch 3,620  of  6,637.    Elapsed: 0:06:39.
#   Batch 3,630  of  6,637.    Elapsed: 0:06:40.
#   Batch 3,640  of  6,637.    Elapsed: 0:06:42.
#   Batch 3,650  of  6,637.    Elapsed: 0:06:43.
#   Batch 3,660  of  6,637.    Elapsed: 0:06:44.
#   Batch 3,670  of  6,637.    Elapsed: 0:06:45.
#   Batch 3,680  of  6,637.    Elapsed: 0:06:46.
#   Batch 3,690  of  6,637.    Elapsed: 0:06:47.
#   Batch 3,700  of  6,637.    Elapsed: 0:06:48.
#   Batch 3,710  of  6,637.    Elapsed: 0:06:49.
#   Batch 3,720  of  6,637.    Elapsed: 0:06:50.
#   Batch 3,730  of  6,637.    Elapsed: 0:06:51.
#   Batch 3,740  of  6,637.    Elapsed: 0:06:52.
#   Batch 3,750  of  6,637.    Elapsed: 0:06:53.
#   Batch 3,760  of  6,637.    Elapsed: 0:06:54.
#   Batch 3,770  of  6,637.    Elapsed: 0:06:56.
#   Batch 3,780  of  6,637.    Elapsed: 0:06:57.
#   Batch 3,790  of  6,637.    Elapsed: 0:06:58.
#   Batch 3,800  of  6,637.    Elapsed: 0:06:59.
#   Batch 3,810  of  6,637.    Elapsed: 0:07:00.
#   Batch 3,820  of  6,637.    Elapsed: 0:07:01.
#   Batch 3,830  of  6,637.    Elapsed: 0:07:02.
#   Batch 3,840  of  6,637.    Elapsed: 0:07:03.
#   Batch 3,850  of  6,637.    Elapsed: 0:07:04.
#   Batch 3,860  of  6,637.    Elapsed: 0:07:05.
#   Batch 3,870  of  6,637.    Elapsed: 0:07:06.
#   Batch 3,880  of  6,637.    Elapsed: 0:07:07.
#   Batch 3,890  of  6,637.    Elapsed: 0:07:09.
#   Batch 3,900  of  6,637.    Elapsed: 0:07:10.
#   Batch 3,910  of  6,637.    Elapsed: 0:07:11.
#   Batch 3,920  of  6,637.    Elapsed: 0:07:12.
#   Batch 3,930  of  6,637.    Elapsed: 0:07:13.
#   Batch 3,940  of  6,637.    Elapsed: 0:07:14.
#   Batch 3,950  of  6,637.    Elapsed: 0:07:15.
#   Batch 3,960  of  6,637.    Elapsed: 0:07:16.
#   Batch 3,970  of  6,637.    Elapsed: 0:07:17.
#   Batch 3,980  of  6,637.    Elapsed: 0:07:18.
#   Batch 3,990  of  6,637.    Elapsed: 0:07:19.
#   Batch 4,000  of  6,637.    Elapsed: 0:07:20.
#   Batch 4,010  of  6,637.    Elapsed: 0:07:21.
#   Batch 4,020  of  6,637.    Elapsed: 0:07:23.
#   Batch 4,030  of  6,637.    Elapsed: 0:07:24.
#   Batch 4,040  of  6,637.    Elapsed: 0:07:25.
#   Batch 4,050  of  6,637.    Elapsed: 0:07:26.
#   Batch 4,060  of  6,637.    Elapsed: 0:07:27.
#   Batch 4,070  of  6,637.    Elapsed: 0:07:28.
#   Batch 4,080  of  6,637.    Elapsed: 0:07:29.
#   Batch 4,090  of  6,637.    Elapsed: 0:07:30.
#   Batch 4,100  of  6,637.    Elapsed: 0:07:31.
#   Batch 4,110  of  6,637.    Elapsed: 0:07:32.
#   Batch 4,120  of  6,637.    Elapsed: 0:07:33.
#   Batch 4,130  of  6,637.    Elapsed: 0:07:34.
#   Batch 4,140  of  6,637.    Elapsed: 0:07:35.
#   Batch 4,150  of  6,637.    Elapsed: 0:07:36.
#   Batch 4,160  of  6,637.    Elapsed: 0:07:38.
#   Batch 4,170  of  6,637.    Elapsed: 0:07:39.
#   Batch 4,180  of  6,637.    Elapsed: 0:07:40.
#   Batch 4,190  of  6,637.    Elapsed: 0:07:41.
#   Batch 4,200  of  6,637.    Elapsed: 0:07:42.
#   Batch 4,210  of  6,637.    Elapsed: 0:07:43.
#   Batch 4,220  of  6,637.    Elapsed: 0:07:44.
#   Batch 4,230  of  6,637.    Elapsed: 0:07:45.
#   Batch 4,240  of  6,637.    Elapsed: 0:07:46.
#   Batch 4,250  of  6,637.    Elapsed: 0:07:47.
#   Batch 4,260  of  6,637.    Elapsed: 0:07:48.
#   Batch 4,270  of  6,637.    Elapsed: 0:07:49.
#   Batch 4,280  of  6,637.    Elapsed: 0:07:50.
#   Batch 4,290  of  6,637.    Elapsed: 0:07:51.
#   Batch 4,300  of  6,637.    Elapsed: 0:07:53.
#   Batch 4,310  of  6,637.    Elapsed: 0:07:54.
#   Batch 4,320  of  6,637.    Elapsed: 0:07:55.
#   Batch 4,330  of  6,637.    Elapsed: 0:07:56.
#   Batch 4,340  of  6,637.    Elapsed: 0:07:57.
#   Batch 4,350  of  6,637.    Elapsed: 0:07:58.
#   Batch 4,360  of  6,637.    Elapsed: 0:07:59.
#   Batch 4,370  of  6,637.    Elapsed: 0:08:00.
#   Batch 4,380  of  6,637.    Elapsed: 0:08:01.
#   Batch 4,390  of  6,637.    Elapsed: 0:08:02.
#   Batch 4,400  of  6,637.    Elapsed: 0:08:03.
#   Batch 4,410  of  6,637.    Elapsed: 0:08:04.
#   Batch 4,420  of  6,637.    Elapsed: 0:08:05.
#   Batch 4,430  of  6,637.    Elapsed: 0:08:06.
#   Batch 4,440  of  6,637.    Elapsed: 0:08:08.
#   Batch 4,450  of  6,637.    Elapsed: 0:08:09.
#   Batch 4,460  of  6,637.    Elapsed: 0:08:10.
#   Batch 4,470  of  6,637.    Elapsed: 0:08:11.
#   Batch 4,480  of  6,637.    Elapsed: 0:08:12.
#   Batch 4,490  of  6,637.    Elapsed: 0:08:13.
#   Batch 4,500  of  6,637.    Elapsed: 0:08:14.
#   Batch 4,510  of  6,637.    Elapsed: 0:08:15.
#   Batch 4,520  of  6,637.    Elapsed: 0:08:16.
#   Batch 4,530  of  6,637.    Elapsed: 0:08:17.
#   Batch 4,540  of  6,637.    Elapsed: 0:08:18.
#   Batch 4,550  of  6,637.    Elapsed: 0:08:19.
#   Batch 4,560  of  6,637.    Elapsed: 0:08:20.
#   Batch 4,570  of  6,637.    Elapsed: 0:08:21.
#   Batch 4,580  of  6,637.    Elapsed: 0:08:23.
#   Batch 4,590  of  6,637.    Elapsed: 0:08:24.
#   Batch 4,600  of  6,637.    Elapsed: 0:08:25.
#   Batch 4,610  of  6,637.    Elapsed: 0:08:26.
#   Batch 4,620  of  6,637.    Elapsed: 0:08:27.
#   Batch 4,630  of  6,637.    Elapsed: 0:08:28.
#   Batch 4,640  of  6,637.    Elapsed: 0:08:29.
#   Batch 4,650  of  6,637.    Elapsed: 0:08:30.
#   Batch 4,660  of  6,637.    Elapsed: 0:08:31.
#   Batch 4,670  of  6,637.    Elapsed: 0:08:32.
#   Batch 4,680  of  6,637.    Elapsed: 0:08:33.
#   Batch 4,690  of  6,637.    Elapsed: 0:08:34.
#   Batch 4,700  of  6,637.    Elapsed: 0:08:35.
#   Batch 4,710  of  6,637.    Elapsed: 0:08:37.
#   Batch 4,720  of  6,637.    Elapsed: 0:08:38.
#   Batch 4,730  of  6,637.    Elapsed: 0:08:39.
#   Batch 4,740  of  6,637.    Elapsed: 0:08:40.
#   Batch 4,750  of  6,637.    Elapsed: 0:08:41.
#   Batch 4,760  of  6,637.    Elapsed: 0:08:42.
#   Batch 4,770  of  6,637.    Elapsed: 0:08:43.
#   Batch 4,780  of  6,637.    Elapsed: 0:08:44.
#   Batch 4,790  of  6,637.    Elapsed: 0:08:45.
#   Batch 4,800  of  6,637.    Elapsed: 0:08:46.
#   Batch 4,810  of  6,637.    Elapsed: 0:08:47.
#   Batch 4,820  of  6,637.    Elapsed: 0:08:48.
#   Batch 4,830  of  6,637.    Elapsed: 0:08:49.
#   Batch 4,840  of  6,637.    Elapsed: 0:08:51.
#   Batch 4,850  of  6,637.    Elapsed: 0:08:52.
#   Batch 4,860  of  6,637.    Elapsed: 0:08:53.
#   Batch 4,870  of  6,637.    Elapsed: 0:08:54.
#   Batch 4,880  of  6,637.    Elapsed: 0:08:55.
#   Batch 4,890  of  6,637.    Elapsed: 0:08:56.
#   Batch 4,900  of  6,637.    Elapsed: 0:08:57.
#   Batch 4,910  of  6,637.    Elapsed: 0:08:58.
#   Batch 4,920  of  6,637.    Elapsed: 0:08:59.
#   Batch 4,930  of  6,637.    Elapsed: 0:09:00.
#   Batch 4,940  of  6,637.    Elapsed: 0:09:01.
#   Batch 4,950  of  6,637.    Elapsed: 0:09:02.
#   Batch 4,960  of  6,637.    Elapsed: 0:09:03.
#   Batch 4,970  of  6,637.    Elapsed: 0:09:05.
#   Batch 4,980  of  6,637.    Elapsed: 0:09:06.
#   Batch 4,990  of  6,637.    Elapsed: 0:09:07.
#   Batch 5,000  of  6,637.    Elapsed: 0:09:08.
#   Batch 5,010  of  6,637.    Elapsed: 0:09:09.
#   Batch 5,020  of  6,637.    Elapsed: 0:09:10.
#   Batch 5,030  of  6,637.    Elapsed: 0:09:11.
#   Batch 5,040  of  6,637.    Elapsed: 0:09:12.
#   Batch 5,050  of  6,637.    Elapsed: 0:09:13.
#   Batch 5,060  of  6,637.    Elapsed: 0:09:14.
#   Batch 5,070  of  6,637.    Elapsed: 0:09:15.
#   Batch 5,080  of  6,637.    Elapsed: 0:09:16.
#   Batch 5,090  of  6,637.    Elapsed: 0:09:17.
#   Batch 5,100  of  6,637.    Elapsed: 0:09:18.
#   Batch 5,110  of  6,637.    Elapsed: 0:09:19.
#   Batch 5,120  of  6,637.    Elapsed: 0:09:21.
#   Batch 5,130  of  6,637.    Elapsed: 0:09:22.
#   Batch 5,140  of  6,637.    Elapsed: 0:09:23.
#   Batch 5,150  of  6,637.    Elapsed: 0:09:24.
#   Batch 5,160  of  6,637.    Elapsed: 0:09:25.
#   Batch 5,170  of  6,637.    Elapsed: 0:09:26.
#   Batch 5,180  of  6,637.    Elapsed: 0:09:27.
#   Batch 5,190  of  6,637.    Elapsed: 0:09:28.
#   Batch 5,200  of  6,637.    Elapsed: 0:09:29.
#   Batch 5,210  of  6,637.    Elapsed: 0:09:30.
#   Batch 5,220  of  6,637.    Elapsed: 0:09:31.
#   Batch 5,230  of  6,637.    Elapsed: 0:09:32.
#   Batch 5,240  of  6,637.    Elapsed: 0:09:33.
#   Batch 5,250  of  6,637.    Elapsed: 0:09:34.
#   Batch 5,260  of  6,637.    Elapsed: 0:09:36.
#   Batch 5,270  of  6,637.    Elapsed: 0:09:37.
#   Batch 5,280  of  6,637.    Elapsed: 0:09:38.
#   Batch 5,290  of  6,637.    Elapsed: 0:09:39.
#   Batch 5,300  of  6,637.    Elapsed: 0:09:40.
#   Batch 5,310  of  6,637.    Elapsed: 0:09:41.
#   Batch 5,320  of  6,637.    Elapsed: 0:09:42.
#   Batch 5,330  of  6,637.    Elapsed: 0:09:43.
#   Batch 5,340  of  6,637.    Elapsed: 0:09:44.
#   Batch 5,350  of  6,637.    Elapsed: 0:09:45.
#   Batch 5,360  of  6,637.    Elapsed: 0:09:46.
#   Batch 5,370  of  6,637.    Elapsed: 0:09:47.
#   Batch 5,380  of  6,637.    Elapsed: 0:09:49.
#   Batch 5,390  of  6,637.    Elapsed: 0:09:50.
#   Batch 5,400  of  6,637.    Elapsed: 0:09:51.
#   Batch 5,410  of  6,637.    Elapsed: 0:09:52.
#   Batch 5,420  of  6,637.    Elapsed: 0:09:53.
#   Batch 5,430  of  6,637.    Elapsed: 0:09:54.
#   Batch 5,440  of  6,637.    Elapsed: 0:09:55.
#   Batch 5,450  of  6,637.    Elapsed: 0:09:56.
#   Batch 5,460  of  6,637.    Elapsed: 0:09:57.
#   Batch 5,470  of  6,637.    Elapsed: 0:09:58.
#   Batch 5,480  of  6,637.    Elapsed: 0:09:59.
#   Batch 5,490  of  6,637.    Elapsed: 0:10:00.
#   Batch 5,500  of  6,637.    Elapsed: 0:10:01.
#   Batch 5,510  of  6,637.    Elapsed: 0:10:02.
#   Batch 5,520  of  6,637.    Elapsed: 0:10:04.
#   Batch 5,530  of  6,637.    Elapsed: 0:10:05.
#   Batch 5,540  of  6,637.    Elapsed: 0:10:06.
#   Batch 5,550  of  6,637.    Elapsed: 0:10:07.
#   Batch 5,560  of  6,637.    Elapsed: 0:10:08.
#   Batch 5,570  of  6,637.    Elapsed: 0:10:09.
#   Batch 5,580  of  6,637.    Elapsed: 0:10:10.
#   Batch 5,590  of  6,637.    Elapsed: 0:10:11.
#   Batch 5,600  of  6,637.    Elapsed: 0:10:12.
#   Batch 5,610  of  6,637.    Elapsed: 0:10:13.
#   Batch 5,620  of  6,637.    Elapsed: 0:10:14.
#   Batch 5,630  of  6,637.    Elapsed: 0:10:15.
#   Batch 5,640  of  6,637.    Elapsed: 0:10:16.
#   Batch 5,650  of  6,637.    Elapsed: 0:10:18.
#   Batch 5,660  of  6,637.    Elapsed: 0:10:19.
#   Batch 5,670  of  6,637.    Elapsed: 0:10:20.
#   Batch 5,680  of  6,637.    Elapsed: 0:10:21.
#   Batch 5,690  of  6,637.    Elapsed: 0:10:22.
#   Batch 5,700  of  6,637.    Elapsed: 0:10:23.
#   Batch 5,710  of  6,637.    Elapsed: 0:10:24.
#   Batch 5,720  of  6,637.    Elapsed: 0:10:25.
#   Batch 5,730  of  6,637.    Elapsed: 0:10:26.
#   Batch 5,740  of  6,637.    Elapsed: 0:10:27.
#   Batch 5,750  of  6,637.    Elapsed: 0:10:28.
#   Batch 5,760  of  6,637.    Elapsed: 0:10:29.
#   Batch 5,770  of  6,637.    Elapsed: 0:10:30.
#   Batch 5,780  of  6,637.    Elapsed: 0:10:31.
#   Batch 5,790  of  6,637.    Elapsed: 0:10:33.
#   Batch 5,800  of  6,637.    Elapsed: 0:10:34.
#   Batch 5,810  of  6,637.    Elapsed: 0:10:35.
#   Batch 5,820  of  6,637.    Elapsed: 0:10:36.
#   Batch 5,830  of  6,637.    Elapsed: 0:10:37.
#   Batch 5,840  of  6,637.    Elapsed: 0:10:38.
#   Batch 5,850  of  6,637.    Elapsed: 0:10:39.
#   Batch 5,860  of  6,637.    Elapsed: 0:10:40.
#   Batch 5,870  of  6,637.    Elapsed: 0:10:41.
#   Batch 5,880  of  6,637.    Elapsed: 0:10:42.
#   Batch 5,890  of  6,637.    Elapsed: 0:10:43.
#   Batch 5,900  of  6,637.    Elapsed: 0:10:44.
#   Batch 5,910  of  6,637.    Elapsed: 0:10:45.
#   Batch 5,920  of  6,637.    Elapsed: 0:10:46.
#   Batch 5,930  of  6,637.    Elapsed: 0:10:48.
#   Batch 5,940  of  6,637.    Elapsed: 0:10:49.
#   Batch 5,950  of  6,637.    Elapsed: 0:10:50.
#   Batch 5,960  of  6,637.    Elapsed: 0:10:51.
#   Batch 5,970  of  6,637.    Elapsed: 0:10:52.
#   Batch 5,980  of  6,637.    Elapsed: 0:10:53.
#   Batch 5,990  of  6,637.    Elapsed: 0:10:54.
#   Batch 6,000  of  6,637.    Elapsed: 0:10:55.
#   Batch 6,010  of  6,637.    Elapsed: 0:10:56.
#   Batch 6,020  of  6,637.    Elapsed: 0:10:57.
#   Batch 6,030  of  6,637.    Elapsed: 0:10:58.
#   Batch 6,040  of  6,637.    Elapsed: 0:10:59.
#   Batch 6,050  of  6,637.    Elapsed: 0:11:00.
#   Batch 6,060  of  6,637.    Elapsed: 0:11:01.
#   Batch 6,070  of  6,637.    Elapsed: 0:11:03.
#   Batch 6,080  of  6,637.    Elapsed: 0:11:04.
#   Batch 6,090  of  6,637.    Elapsed: 0:11:05.
#   Batch 6,100  of  6,637.    Elapsed: 0:11:06.
#   Batch 6,110  of  6,637.    Elapsed: 0:11:07.
#   Batch 6,120  of  6,637.    Elapsed: 0:11:08.
#   Batch 6,130  of  6,637.    Elapsed: 0:11:09.
#   Batch 6,140  of  6,637.    Elapsed: 0:11:10.
#   Batch 6,150  of  6,637.    Elapsed: 0:11:11.
#   Batch 6,160  of  6,637.    Elapsed: 0:11:12.
#   Batch 6,170  of  6,637.    Elapsed: 0:11:13.
#   Batch 6,180  of  6,637.    Elapsed: 0:11:14.
#   Batch 6,190  of  6,637.    Elapsed: 0:11:15.
#   Batch 6,200  of  6,637.    Elapsed: 0:11:16.
#   Batch 6,210  of  6,637.    Elapsed: 0:11:18.
#   Batch 6,220  of  6,637.    Elapsed: 0:11:19.
#   Batch 6,230  of  6,637.    Elapsed: 0:11:20.
#   Batch 6,240  of  6,637.    Elapsed: 0:11:21.
#   Batch 6,250  of  6,637.    Elapsed: 0:11:22.
#   Batch 6,260  of  6,637.    Elapsed: 0:11:23.
#   Batch 6,270  of  6,637.    Elapsed: 0:11:24.
#   Batch 6,280  of  6,637.    Elapsed: 0:11:25.
#   Batch 6,290  of  6,637.    Elapsed: 0:11:26.
#   Batch 6,300  of  6,637.    Elapsed: 0:11:27.
#   Batch 6,310  of  6,637.    Elapsed: 0:11:28.
#   Batch 6,320  of  6,637.    Elapsed: 0:11:29.
#   Batch 6,330  of  6,637.    Elapsed: 0:11:30.
#   Batch 6,340  of  6,637.    Elapsed: 0:11:31.
#   Batch 6,350  of  6,637.    Elapsed: 0:11:33.
#   Batch 6,360  of  6,637.    Elapsed: 0:11:34.
#   Batch 6,370  of  6,637.    Elapsed: 0:11:35.
#   Batch 6,380  of  6,637.    Elapsed: 0:11:36.
#   Batch 6,390  of  6,637.    Elapsed: 0:11:37.
#   Batch 6,400  of  6,637.    Elapsed: 0:11:38.
#   Batch 6,410  of  6,637.    Elapsed: 0:11:39.
#   Batch 6,420  of  6,637.    Elapsed: 0:11:40.
#   Batch 6,430  of  6,637.    Elapsed: 0:11:41.
#   Batch 6,440  of  6,637.    Elapsed: 0:11:42.
#   Batch 6,450  of  6,637.    Elapsed: 0:11:43.
#   Batch 6,460  of  6,637.    Elapsed: 0:11:44.
#   Batch 6,470  of  6,637.    Elapsed: 0:11:46.
#   Batch 6,480  of  6,637.    Elapsed: 0:11:47.
#   Batch 6,490  of  6,637.    Elapsed: 0:11:48.
#   Batch 6,500  of  6,637.    Elapsed: 0:11:49.
#   Batch 6,510  of  6,637.    Elapsed: 0:11:50.
#   Batch 6,520  of  6,637.    Elapsed: 0:11:51.
#   Batch 6,530  of  6,637.    Elapsed: 0:11:52.
#   Batch 6,540  of  6,637.    Elapsed: 0:11:53.
#   Batch 6,550  of  6,637.    Elapsed: 0:11:54.
#   Batch 6,560  of  6,637.    Elapsed: 0:11:55.
#   Batch 6,570  of  6,637.    Elapsed: 0:11:56.
#   Batch 6,580  of  6,637.    Elapsed: 0:11:57.
#   Batch 6,590  of  6,637.    Elapsed: 0:11:58.
#   Batch 6,600  of  6,637.    Elapsed: 0:12:00.
#   Batch 6,610  of  6,637.    Elapsed: 0:12:01.
#   Batch 6,620  of  6,637.    Elapsed: 0:12:02.
#   Batch 6,630  of  6,637.    Elapsed: 0:12:03.
#
#   Average training loss generetor: 0.707
#   Average training loss discriminator: 1.130
#   Training epcoh took: 0:12:03
#
# Running Test...
#   Accuracy: 0.329
#   Test Loss: 1.123
#   Test took: 0:00:26
